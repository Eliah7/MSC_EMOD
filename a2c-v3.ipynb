# %%
import os
import sys
# print(sys.path)
module_path = os.path.abspath(os.path.join('.'))
# print(module_path)
if module_path not in sys.path:
    sys.path.append(module_path)
# print(sys.path)

# %% [markdown]
# ## Initiate RAY

# %%
from ray.rllib.algorithms.a3c import A3CConfig
from ray import tune, air
import ray
from env.environment import MalariaEnvironment

# %%
ray.shutdown()
ray.init(ignore_reinit_error=True, num_cpus=1,local_mode=True)
# ray.init()
# Out:
# 2023-08-18 06:31:00,943	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8268
# RayContext(dashboard_url='127.0.0.1:8268', python_version='3.8.8', ray_version='2.2.0', ray_commit='b6af0887ee5f2e460202133791ad941a41f15beb', address_info={'node_ip_address': '10.8.13.207', 'raylet_ip_address': '10.8.13.207', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2023-08-18_06-30-56_291953_66604/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2023-08-18_06-30-56_291953_66604/sockets/raylet', 'webui_url': '127.0.0.1:8268', 'session_dir': '/tmp/ray/session_2023-08-18_06-30-56_291953_66604', 'metrics_export_port': 62149, 'gcs_address': '10.8.13.207:35508', 'address': '10.8.13.207:35508', 'dashboard_agent_listen_port': 52365, 'node_id': 'ea5d9e33516f9d6812e631f0e99452ef4132a798a9719616eba367ea'})

# %% [markdown]
# ## Prepare the Environment

# %%
from ray.tune.registry import register_env

def env_creator(env_config):
    return MalariaEnvironment()  # return an env instance

register_env("MalariaEnvironment", env_creator)
env = MalariaEnvironment()

config = A3CConfig()

# config = config.training(lr=0.01) #.rollouts(num_rollout_workers=1)
# config = config.framework(framework='tf2')

# Set the config object's env.
config = config.environment(env="MalariaEnvironment")

# %%
from scipy.stats import linregress, sem

# %%
def measure_random_performance_for_env(env, episodes=1000, verbose=False):
    import numpy as np
    # Reset the env.
    env.reset()

    # Number of episodes already done.
    num_episodes = 0
    # Current episode's accumulated reward.
    episode_reward = 0.0
    # Collect all episode rewards here to be able to calculate a random baseline reward.
    episode_rewards = []

    # Enter while loop (to step through the episode).
    while num_episodes < episodes:
        # Produce a random action.
        action = env.action_space.sample()

        # Send the action to the env's `step()` method to receive: obs, reward, done, and info.
        obs, reward, done, _ = env.step(action)
        episode_reward += reward

        # Check, whether the episde is done, if yes, reset and increase episode counter.
        if done:
            if verbose:
                print(f"Episode done - accumulated reward={episode_reward}")
            elif num_episodes % 100 == 0:
                print(f" {num_episodes} ", end="")
            elif num_episodes % 10 == 0:
                print(".", end="")
            num_episodes += 1
            env.reset()
            episode_rewards.append(episode_reward)
            episode_reward = 0.0

    # Print out and return mean episode reward (and standard error of the mean).
    env_mean_random_reward = np.mean(episode_rewards)

    print(f"\n\nMean episode reward when acting randomly: {env_mean_random_reward:.2f}+/-{sem(episode_rewards):.2f}")

    return env_mean_random_reward, sem(episode_rewards), episode_rewards

# %%
env_mean_random_reward, rewards_mean, rewards = measure_random_performance_for_env(env, episodes=100)
# Out:
# ACTION OrderedDict([('IRS', array([0.36967844], dtype=float32)), ('ITNS', array([0.2642208], dtype=float32))])
# Setting IRS to 0.36967843770980835
# Setting ITNS to 0.26422080397605896
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 37142 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 26544 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 37154 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100016 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 36939 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 37249 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100032 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 37208 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100033 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 36823 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100046 Infected: 13701
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 36731 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100053 Infected: 13701
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 36874 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100058 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 36998 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100065 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 36827 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100071 Infected: 13701
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 36803 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100082 Infected: 13700
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 37066 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13700
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 36935 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100091 Infected: 13700
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 37247 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100098 Infected: 13700
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 36766 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 37009 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 36764 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 36740 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:17 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 34297 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 33129 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 32346 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 32815 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 32684 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 32576 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 32697 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 32470 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 32429 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 32331 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 32127 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:23 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:23 [0] [I] [Controller] Exiting execute_internal
# 00:00:23 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 83.00948
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -92.13814666666667
#  0 ACTION OrderedDict([('IRS', array([0.80436516], dtype=float32)), ('ITNS', array([0.920039], dtype=float32))])
# Setting IRS to 0.8043651580810547
# Setting ITNS to 0.9200389981269836
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80763 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 92011 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80543 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100016 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80454 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80385 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100032 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80566 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100033 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80566 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100046 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80388 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100053 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80563 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100058 Infected: 13701
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80545 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100065 Infected: 13701
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80251 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100071 Infected: 13701
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80485 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100082 Infected: 13700
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80638 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13700
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80376 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100091 Infected: 13700
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80577 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100098 Infected: 13700
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80366 'IRSHousingModification' interventions at node 340461476
# 00:00:16 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80384 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80177 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79655 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74690 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 72199 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 70791 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 70972 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 70809 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 70802 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 70678 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 70655 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 70491 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:28 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 70459 'IRSHousingModification' interventions at node 340461476
# 00:00:30 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:31 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 70257 'IRSHousingModification' interventions at node 340461476
# 00:00:31 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:31 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:31 [0] [I] [Controller] Exiting execute_internal
# 00:00:31 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 181.8892
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -191.01786666666666
# ACTION OrderedDict([('IRS', array([0.8198788], dtype=float32)), ('ITNS', array([0.5990432], dtype=float32))])
# Setting IRS to 0.8198788166046143
# Setting ITNS to 0.5990431904792786
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:01 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:01 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:01 [0] [I] [Simulation] Merging node rank maps...
# 00:00:01 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:01 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 82255 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 60115 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 82080 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100016 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 81988 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 81920 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100032 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 82123 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100033 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 82115 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100046 Infected: 13701
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 81915 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100053 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 82150 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100058 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 82080 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100065 Infected: 13701
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 81842 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100071 Infected: 13701
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 82001 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100082 Infected: 13700
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 82147 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13700
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 81921 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100091 Infected: 13700
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 82134 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100098 Infected: 13700
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 81990 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 81966 'IRSHousingModification' interventions at node 340461476
# 00:00:16 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 81705 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:17 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 81157 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 76138 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 73591 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 72160 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 72298 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 72270 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 72137 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 71997 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 71997 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 71857 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 71802 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 71584 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:26 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:26 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:26 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:26 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:26 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:26 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:26 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:26 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:26 [0] [I] [Controller] Exiting execute_internal
# 00:00:26 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 184.11992
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -193.24858666666668
# ACTION OrderedDict([('IRS', array([0.96077275], dtype=float32)), ('ITNS', array([0.74644613], dtype=float32))])
# Setting IRS to 0.9607727527618408
# Setting ITNS to 0.7464461326599121
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:01 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:01 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:01 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:01 [0] [I] [Climate] Initialize
# 00:00:01 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:01 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:01 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:01 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:01 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96033 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74763 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96236 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100016 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96179 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96085 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100032 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96159 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100033 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96161 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100046 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96084 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100053 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96185 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100058 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96185 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100065 Infected: 13701
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96100 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100071 Infected: 13701
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96166 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100082 Infected: 13700
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96241 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13700
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96172 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100091 Infected: 13700
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96173 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100098 Infected: 13700
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96195 'IRSHousingModification' interventions at node 340461476
# 00:00:16 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 96081 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:17 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 95786 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 95113 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 89192 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 86224 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 84696 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 84727 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 84481 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 84503 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 84295 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 84236 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 84044 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 84089 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 83879 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:28 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:28 [0] [I] [Controller] Exiting execute_internal
# 00:00:28 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 215.8996
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -225.02826666666667
# ACTION OrderedDict([('IRS', array([0.3995401], dtype=float32)), ('ITNS', array([0.90879697], dtype=float32))])
# Setting IRS to 0.39954009652137756
# Setting ITNS to 0.9087969660758972
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# ...
# 00:00:14 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 49720 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 49576 'IRSHousingModification' interventions at node 340461476
# 00:00:16 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 49316 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46330 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 44583 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 43797 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 43977 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 44047 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 43729 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 43967 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 43579 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 43795 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 43557 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 43497 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:24 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:24 [0] [I] [Controller] Exiting execute_internal
# 00:00:24 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 113.57503
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -122.70369666666667
# ACTION OrderedDict([('IRS', array([0.66284406], dtype=float32)), ('ITNS', array([0.79733336], dtype=float32))])
# Setting IRS to 0.6628440618515015
# Setting ITNS to 0.7973333597183228
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:01 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:01 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:01 [0] [I] [Simulation] Merging node rank maps...
# 00:00:01 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:01 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:01 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:01 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:01 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:01 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:01 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66595 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79794 'SimpleBednet' interventions at node 340461476
# 00:00:02 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66262 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100016 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66405 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66256 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100032 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66292 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100033 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66394 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100046 Infected: 13701
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66147 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100053 Infected: 13701
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66223 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100058 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66535 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100065 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66027 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100071 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66360 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100082 Infected: 13700
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66635 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13700
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66114 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100091 Infected: 13700
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66418 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100098 Infected: 13700
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66111 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66188 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66118 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65680 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:17 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 61535 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 59559 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 58375 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 58485 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 58413 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 58297 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 58380 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 58208 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 58040 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 58112 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 57996 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:23 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:23 [0] [I] [Controller] Exiting execute_internal
# 00:00:23 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 150.04508
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -159.1737466666667
# ACTION OrderedDict([('IRS', array([0.89497817], dtype=float32)), ('ITNS', array([0.29853275], dtype=float32))])
# Setting IRS to 0.8949781656265259
# Setting ITNS to 0.29853275418281555
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD

# %%
# env_mean_random_reward, rewards_mean, random_rewards

# %% [markdown]
# ## Run Tune Config

# %%
from ray.rllib.algorithms.a3c import A3CConfig
from ray import tune, air
import ray
import json
from env.environment import MalariaEnvironment
from ray.tune.logger import pretty_print
ray.init(ignore_reinit_error=True, num_cpus=1, local_mode=True)

# Parallel environments
from ray.tune.registry import register_env

def env_creator(env_config):
    return MalariaEnvironment()  # return an env instance

register_env("MalariaEnvironment", env_creator)
env = MalariaEnvironment()

config = A3CConfig()
# Print out some default values.
# print(config.sample_async)  
# Update the config object.
config = config.training(lr=tune.grid_search([0.1, 0.001, 0.0001]))
# config = config.training(lr=0.01)
# config = config.training(lr=tune.grid_search([0.001, 0.01, 0.1]))

# config = config.rollouts(num_rollout_workers=1)
config = config.framework()

# Set the config object's env.
config = config.environment(env="MalariaEnvironment") 
# Use to_dict() to get the old-style python config dict
# when running with tune.

pretty_print(config.to_dict())

algo = config.build()  
# for i in range(10):
#     # print(f"Iteration Count: {i}")
#     training_results = algo.train()

# print(pretty_print(training_results))

# algo.train()

# %%
policy = algo.get_policy()

print(policy.model.base_model.summary())

# %%
config_space = {
    'lr': tune.grid_search([0.001, 0.01, 0.1],
        )
}

# %%
tune.Tuner(  
    "A3C",
     param_space=config.to_dict(),
     run_config=air.RunConfig(local_dir="./tensorboard", name="a2c")
).fit()

# %%
random_rewards = rewards

# %%
# rewardsrewards

# %%
# Train for n more iterations (timesteps) and collect n-arm rewards.
import matplotlib.pyplot as plt
import numpy as np
rewards = []
for i in range(100):
    # Run a single timestep in the environment and update
    # the model immediately on the received reward.
    result = algo.train()
    # Extract reward from results.
    #rewards.extend(result["hist_stats"]["episode_reward"]
    rewards.append(result["episode_reward_mean"])
    if i % 500 == 0:
        print(f" {i} ", end="")
    elif i % 100 == 0:
        print(".", end="")

# Plot per-timestep (episode) rewards.

# %%
len(rewards)

# %%
plt.figure(figsize=(10,7))
start_at = 0
smoothing_win = 200
x = list(range(start_at, len(rewards)))
y = [np.nanmean(rewards[max(i - smoothing_win, 0):i + 1]) for i in range(start_at, len(rewards))]
plt.plot(x, y)
plt.title("Mean reward - Random Model")
plt.xlabel("Time/Training steps")

x_ = list(range(start_at, len(random_rewards)))
y_ = [np.nanmean(random_rewards[max(i - smoothing_win, 0):i + 1]) for i in range(start_at, len(random_rewards))]
plt.plot(x_, y_, color="c", linestyle="-")
# Add mean random baseline reward (red line).
# plt.axhline(y=env_mean_random_reward, color="r", linestyle="-")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-52b2b74f2443> in <module>
#       8 plt.xlabel("Time/Training steps")
#       9
# ---> 10 x_ = list(range(start_at, len(random_rewards)))
#      11 y_ = [np.nanmean(random_rewards[max(i - smoothing_win, 0):i + 1]) for i in range(start_at, len(random_rewards))]
#      12 plt.plot(x_, y_, color="c", linestyle="-")
#
# NameError: name 'random_rewards' is not defined

# %%
# %matplotlib inline
plt.plot(x, y, label='A2C')
plt.title("Mean reward - A2C Model")
plt.xlabel("Time/Training steps")

# Add mean random baseline reward (red line).
plt.axhline(y=env_mean_random_reward, color="r", linestyle="-", label='Random Model')
plt.legend()
plt.show()

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9063a9f0e032> in <module>
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
tune.run("A3C", config=config.rollouts(num_rollout_workers=1))
# Out:
# 2023-06-07 12:26:04,041	INFO algorithm_config.py:2503 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also then want to set eager_tracing=True in order to reach similar execution speed as with static-graph mode.
# 2023-06-07 12:26:04,046	INFO algorithm_config.py:2503 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also then want to set eager_tracing=True in order to reach similar execution speed as with static-graph mode.
# 2023-06-07 12:26:04,494	WARNING worker.py:837 -- `ray.get_gpu_ids()` will always return the empty list when called from the driver. This is because Ray does not manage GPU allocations to the driver process.
# :task_name:bundle_reservation_check_func
# :task_name:bundle_reservation_check_func
# :actor_name:A3C
# 2023-06-07 12:26:04,787	INFO algorithm_config.py:2503 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also then want to set eager_tracing=True in order to reach similar execution speed as with static-graph mode.
# 2023-06-07 12:26:04,823	INFO algorithm.py:501 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# :actor_name:A3C
# :actor_name:RolloutWorker
# 2023-06-07 12:26:05,138	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# 2023-06-07 12:26:05,146	WARNING env.py:159 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# :actor_name:RolloutWorker
# ACTION OrderedDict([('IRS', array([0.81606364], dtype=float32)), ('ITNS', array([0.4142474], dtype=float32))])
# Setting IRS to 0.816063642501831
# Setting ITNS to 0.41424739360809326
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ray_results/A3C/A3C_MalariaEnvironment_52880_00000_0_2023-06-07_12-26-04
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [E] [Eradication]
#
# JsonTypeConfigurationException:
# Exception in utils/Configuration.cpp at 630 in GET_CONFIG_STRING.
# While trying to parse json data for param/key >>> Maternal_Antibodies_Type <<< in otherwise valid json segment...
# {
# 	"Acquisition_Blocking_Immunity_Decay_Rate" : 0.01,
# 	"Acquisition_Blocking_Immunity_Duration_Before_Decay" : 90,
# 	"Age_Dependent_Biting_Risk_Type" : "OFF",
# 	"Age_Initialization_Distribution_Type" : "DISTRIBUTION_SIMPLE",
# 	"Air_Temperature_Filename" : "Namawala_single_node_air_temperature_daily.bin",
# 	"Air_Temperature_Offset" : 0,
# 	"Air_Temperature_Variance" : 2,
# 	"Anemia_Mortality_Inverse_Width" : 20,
# 	"Anemia_Mortality_Threshold" : 1.5,
# 	"Anemia_Severe_Inverse_Width" : 20,
# 	"Anemia_Severe_Threshold" : 3,
# 	"Antibody_CSP_Decay_Days" : 90,
# 	"Antibody_CSP_Killing_Inverse_Width" : 1.5,
# 	"Antibody_CSP_Killing_Threshold" : 20,
# 	"Antibody_Capacity_Growth_Rate" : 0.1,
# 	"Antibody_IRBC_Kill_Rate" : 1.5,
# 	"Antibody_Memory_Level" : 0.225,
# 	"Antibody_Stimulation_C50" : 10,
# 	"Antigen_Switch_Rate" : 2e-09,
# 	"Base_Air_Temperature" : 22,
# 	"Base_Gametocyte_Fraction_Male" : 0.2,
# 	"Base_Gametocyte_Mosquito_Survival_Rate" : 0.01,
# 	"Base_Gametocyte_Production_Rate" : 0.02,
# 	"Base_Individual_Sample_Rate" : 1,
# 	"Base_Land_Temperature" : 26,
# 	"Base_Mortality" : 0,
# 	"Base_Rainfall" : 10,
# 	"Base_Relative_Humidity" : 0.75,
# 	"Base_Sporozoite_Survival_Fraction" : 0.25,
# 	"Birth_Rate_Dependence" : "POPULATION_DEP_RATE",
# 	"Birth_Rate_Time_Dependence" : "NONE",
# 	"Campaign_Filename" : "campaign.json",
# 	"Climate_Model" : "CLIMATE_BY_DATA",
# 	"Climate_Update_Resolution" : "CLIMATE_UPDATE_DAY",
# 	"Clinical_Fever_Threshold_High" : 1,
# 	"Clinical_Fever_Threshold_Low" : 0.5,
# 	"Config_Name" : "Full_Malaria_Model",
# 	"Custom_Coordinator_Events" : [],
# 	"Custom_Individual_Events" : [],
# 	"Custom_Node_Events" : [],
# 	"Custom_Reports_Filename" : "",
# 	"Cytokine_Gametocyte_Inactivation" : 0.05,
# 00:00:00 [0] [E] [Eradication]
#
# JsonTypeConfigurationException:
# Exception in utils/Configuration.cpp at 630 in GET_CONFIG_STRING.
# While trying to parse json data for param/key >>> Maternal_Antibodies_Type <<< in otherwise valid json segment...
# {
# 	"Acquisition_Blocking_Immunity_Decay_Rate" : 0.01,
# 	"Acquisition_Blocking_Immunity_Duration_Before_Decay" : 90,
# 	"Age_Dependent_Biting_Risk_Type" : "OFF",
# 	"Age_Initialization_Distribution_Type" : "DISTRIBUTION_SIMPLE",
# 	"Air_Temperature_Filename" : "Namawala_single_node_air_temperature_daily.bin",
# 	"Air_Temperature_Offset" : 0,
# 	"Air_Temperature_Variance" : 2,
# 	"Anemia_Mortality_Inverse_Width" : 20,
# 	"Anemia_Mortality_Threshold" : 1.5,
# 	"Anemia_Severe_Inverse_Width" : 20,
# 	"Anemia_Severe_Threshold" : 3,
# 	"Antibody_CSP_Decay_Days" : 90,
# 	"Antibody_CSP_Killing_Inverse_Width" : 1.5,
# 	"Antibody_CSP_Killing_Threshold" : 20,
# 	"Antibody_Capacity_Growth_Rate" : 0.1,
# 	"Antibody_IRBC_Kill_Rate" : 1.5,
# 	"Death_Rate_Dependence" : "NONDISEASE_MORTALITY_BY_AGE_AND_GENDER",
# 	"Default_Geography_Initial_Node_Population" : 1e+06,
# 	"Default_Geography_Torus_Size" : 10,
# 	"Demographics_Filenames" : [
# 		"Namawala_single_node_demographics.json"
# 	],
# 	"Egg_Hatch_Delay_Distribution" : "NO_DELAY",
# 	"Egg_Hatch_Density_Dependence" : "NO_DENSITY_DEPENDENCE",
# 	"Egg_Saturation_At_Oviposition" : "SATURATION_AT_OVIPOSITION",
# 	"Enable_Aging" : 1,
# 	"Enable_Birth" : 1,
# 	"Enable_Climate_Stochasticity" : 1,
# 	"Enable_Default_Reporting" : 1,
# 	"Enable_Demographics_Birth" : 1,
# 	"Enable_Demographics_Builtin" : 0,
# 	"Enable_Demographics_Reporting" : 1,
# 	"Enable_Demographics_Risk" : 1,
# 	"Enable_Disease_Mortality" : 1,
# 	"Enable_Drought_Egg_Hatch_Delay" : 0,
# 	"Enable_Egg_Mortality" : 0,
# 	"Enable_Heterogeneous_Intranode_Transmission" : 0,
# 	"Enable_Infectivity_Reservoir" : 0,
# 	"Enable_Initial_Prevalence" : 1,
# 	"Enable_Initial_Susceptibility_Distribution" : 0,
# 	"Enable_Interventions" : 1,
# 	"Enable_Maternal_Antibodies_Transmission" : 1,
# 	"Enable_Maternal_Infection_Transmission" : 1,
# 	"Enable_Maternal_Protection" : 1,
# 	"Enable_Natural_Mortality" : 1,
# 	"Enable_Property_Output" : 0,
# 	"Enable_Rainfall_Stochasticity" : 1,
# 	"Enable_Sexual_Combination" : 0,
# 	"Enable_Spatial_Output" : 0,
# 	"Enable_Superinfection" : 1,
# 	"Enable_Susceptibility_Scaling" : 0,
# 	"Enable_Temperature_Dependent_Egg_Hatching" : 0,
# 	"Enable_Termination_On_Zero_Total_Infectivity" : 0,
# 	"Enable_Vector_Aging" : 0,
# 	"Enable_Vector_Migration" : 0,
# 	"Antibody_Memory_Level" : 0.225,
# 	"Antibody_Stimulation_C50" : 10,
# 	"Antigen_Switch_Rate" : 2e-09,
# 	"Base_Air_Temperature" : 22,
# 	"Base_Gametocyte_Fraction_Male" : 0.2,
# 	"Base_Gametocyte_Mosquito_Survival_Rate" : 0.01,
# 	"Base_Gametocyte_Production_Rate" : 0.02,
# 	"Base_Individual_Sample_Rate" : 1,
# 	"Base_Land_Temperature" : 26,
# 	"Base_Mortality" : 0,
# 	"Base_Rainfall" : 10,
# 	"Base_Relative_Humidity" : 0.75,
# 	"Base_Sporozoite_Survival_Fraction" : 0.25,
# 	"Birth_Rate_Dependence" : "POPULATION_DEP_RATE",
# 	"Birth_Rate_Time_Dependence" : "NONE",
# 	"Campaign_Filename" : "campaign.json",
# 	"Climate_Model" : "CLIMATE_BY_DATA",
# 	"Climate_Update_Resolution" : "CLIMATE_UPDATE_DAY",
# 	"Clinical_Fever_Threshold_High" : 1,
# 	"Clinical_Fever_Threshold_Low" : 0.5,
# 	"Config_Name" : "Full_Malaria_Model",
# 	"Custom_Coordinator_Events" : [],
# 	"Custom_Individual_Events" : [],
# 	"Custom_Node_Events" : [],
# 	"Custom_Reports_Filename" : "",
# 	"Cytokine_Gametocyte_Inactivation" : 0.05,
# 	"Death_Rate_Dependence" : "NONDISEASE_MORTALITY_BY_AGE_AND_GENDER",
# 	"Default_Geography_Initial_Node_Population" : 1e+06,
# 	"Default_Geography_Torus_Size" : 10,
# 	"Demographics_Filenames" : [
# 		"Namawala_single_node_demographics.json"
# 	],
# 	"Egg_Hatch_Delay_Distribution" : "NO_DELAY",
# 	"Egg_Hatch_Density_Dependence" : "NO_DENSITY_DEPENDENCE",
# 	"Egg_Saturation_At_Oviposition" : "SATURATION_AT_OVIPOSITION",
# 	"Enable_Aging" : 1,
# 	"Enable_Birth" : 1,
# 	"Enable_Climate_Stochasticity" : 1,
# 	"Enable_Default_Reporting" : 1,
# 	"Enable_Demographics_Birth" : 1,
# 	"Enable_Demographics_Builtin" : 0,
# 	"Enable_Demographics_Reporting" : 1,
# 	"Enable_Demographics_Risk" : 1,
# 	"Enable_Disease_Mortality" : 1,
# 	"Enable_Drought_Egg_Hatch_Delay" : 0,
# 	"Enable_Egg_Mortality" : 0,
# 	"Enable_Heterogeneous_Intranode_Transmission" : 0,
# 	"Enable_Infectivity_Reservoir" : 0,
# 	"Enable_Initial_Prevalence" : 1,
# 	"Enable_Initial_Susceptibility_Distribution" : 0,
# 	"Enable_Interventions" : 1,
# 	"Enable_Maternal_Antibodies_Transmission" : 1,
# 	"Enable_Maternal_Infection_Transmission" : 1,
# 	"Enable_Maternal_Protection" : 1,
# 	"Enable_Natural_Mortality" : 1,
# 	"Enable_Property_Output" : 0,
# 	"Enable_Rainfall_Stochasticity" : 1,
# 	"Enable_Sexual_Combination" : 0,
# 	"Enable_Spatial_Output" : 0,
# 	"Enable_Superinfection" : 1,
# 	"Enable_Susceptibility_Scaling" : 0,
# 	"Enable_Temperature_Dependent_Egg_Hatching" : 0,
# 	"Enable_Termination_On_Zero_Total_Infectivity" : 0,
# 	"Enable_Vector_Aging" : 0,
# 	"Enable_Vector_Migration" : 0,
# 	"Enable_Vector_Mortality" : 1,
# 	"Enable_Vital_Dynamics" : 1,
# 	"Erythropoiesis_Anemia_Effect" : 0,
# 	"Falciparum_MSP_Variants" : 4,
# 	"Falciparum_Nonspecific_Types" : 4,
# 	"Falciparum_PfEMP1_Variants" : 300,
# 	"Fever_Detection_Threshold" : 1,
# 	"Fever_IRBC_Kill_Rate" : 1,
# 	"Fever_Mortality_Inverse_Width" : 10,
# 	"Fever_Mortality_Threshold" : 3,
# 	"Fever_Severe_Inverse_Width" : 10,
# 	"Fever_Severe_Threshold" : 1.5,
# 	"Gametocyte_Stage_Survival_Rate" : 1,
# 	"Genome_Markers" : [],
# 	"HEG_Fecundity_Limiting" : 0,
# 	"HEG_Homing_Rate" : 0,
# 	"HEG_Model" : "OFF",
# 	"Human_Feeding_Mortality" : 1,
# 	"Incubation_Period_Constant" : 7,
# 	"Incubation_Period_Distribution" : "CONSTANT_DISTRIBUTION",
# 	"Individual_Sampling_Type" : "TRACK_ALL",
# 	"Infection_Updates_Per_Timestep" : 24,
# 	"Innate_Immune_Variation_Type" : "NONE",
# 	"Koppen_Filename" : "",
# 	"Land_Temperature_Filename" : "Namawala_single_node_land_temperature_daily.bin",
# 	"Land_Temperature_Offset" : 0,
# 	"Land_Temperature_Variance" : 2,
# 	"Larval_Density_Dependence" : "UNIFORM_WHEN_OVERPOPULATION",
# 	"Load_Balance_Filename" : "",
# 	"MSP1_Merozoite_Kill_Fraction" : 1,
# 	"Malaria_Drug_Params" : {
# 		"Artemether_Lumefantrine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Artemisinin" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Chloroquine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 4,
# 			"Drug_Decay_T2" : 15,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 3,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"GenPreerythrocytic" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"GenTransBlocking" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Primaquine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Quinine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 7,
# 			"Drug_Decay_T2" : 7,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"SP" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Tafenoquine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		}
# 	},
# 	"Malaria_Model" : "MALARIA_MECHANISTIC_MODEL",
# 	"Malaria_Strain_Model" : "FALCIPARUM_RANDOM_STRAIN",
# 	"Maternal_Infection_Transmission_Probability" : 0,
# 	"Max_Individual_Infections" : 5,
# 	"Max_MSP1_Antibody_Growthrate" : 0.02,
# 	"Max_Node_Population_Samples" : 40,
# 	"Mean_Egg_Hatch_Delay" : 0,
# 	"Mean_Sporozoites_Per_Bite" : 110,
# 	"Memory_Usage_Halting_Threshold_Working_Set_MB" : 4000,
# 	"Memory_Usage_Warning_Threshold_Working_Set_MB" : 3500,
# 	"Merozoites_Per_Hepatocyte" : 15000,
# 	"Merozoites_Per_Schizont" : 16,
# 	"Migration_Model" : "NO_MIGRATION",
# 	"Min_Adapted_Response" : 0.01,
# 	"Min_Days_Between_Clinical_Incidents" : 3,
# 	"Minimum_Adult_Age_Years" : 15,
# 	"Mortality_Blocking_Immunity_Decay_Rate" : 0.001,
# 	"Mortality_Blocking_Immunity_Duration_Before_Decay" : 90,
# 	"Enable_Vector_Mortality" : 1,
# 	"Enable_Vital_Dynamics" : 1,
# 	"Erythropoiesis_Anemia_Effect" : 0,
# 	"Falciparum_MSP_Variants" : 4,
# 	"Falciparum_Nonspecific_Types" : 4,
# 	"Falciparum_PfEMP1_Variants" : 300,
# 	"Fever_Detection_Threshold" : 1,
# 	"Fever_IRBC_Kill_Rate" : 1,
# 	"Fever_Mortality_Inverse_Width" : 10,
# 	"Fever_Mortality_Threshold" : 3,
# 	"Fever_Severe_Inverse_Width" : 10,
# 	"Fever_Severe_Threshold" : 1.5,
# 	"Gametocyte_Stage_Survival_Rate" : 1,
# 	"Genome_Markers" : [],
# 	"HEG_Fecundity_Limiting" : 0,
# 	"HEG_Homing_Rate" : 0,
# 	"HEG_Model" : "OFF",
# 	"Human_Feeding_Mortality" : 1,
# 	"Incubation_Period_Constant" : 7,
# 	"Incubation_Period_Distribution" : "CONSTANT_DISTRIBUTION",
# 	"Individual_Sampling_Type" : "TRACK_ALL",
# 	"Infection_Updates_Per_Timestep" : 24,
# 	"Innate_Immune_Variation_Type" : "NONE",
# 	"Koppen_Filename" : "",
# 	"Land_Temperature_Filename" : "Namawala_single_node_land_temperature_daily.bin",
# 	"Land_Temperature_Offset" : 0,
# 	"Land_Temperature_Variance" : 2,
# 	"Larval_Density_Dependence" : "UNIFORM_WHEN_OVERPOPULATION",
# 	"Load_Balance_Filename" : "",
# 	"MSP1_Merozoite_Kill_Fraction" : 1,
# 	"Malaria_Drug_Params" : {
# 		"Artemether_Lumefantrine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Artemisinin" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Chloroquine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 4,
# 			"Drug_Decay_T2" : 15,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 3,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"GenPreerythrocytic" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 	"Mortality_Time_Course" : "DAILY_MORTALITY",
# 	"Mosquito_Weight" : 1,
# 	"New_Diagnostic_Sensitivity" : 0.01,
# 	"Node_Grid_Size" : 0.042,
# 	"Nonspecific_Antibody_Growth_Rate_Factor" : 0.5,
# 	"Nonspecific_Antigenicity_Factor" : 0.3,
# 	"Num_Cores" : 1,
# 	"Number_Basestrains" : 1,
# 	"Number_Of_Asexual_Cycles_Without_Gametocytes" : 1,
# 	"PKPD_Model" : "FIXED_DURATION_CONSTANT_EFFECT",
# 	"Parasite_Mortality_Inverse_Width" : 10,
# 	"Parasite_Mortality_Threshold" : 2e+06,
# 	"Parasite_Severe_Inverse_Width" : 10,
# 	"Parasite_Severe_Threshold" : 1e+06,
# 	"Parasite_Smear_Sensitivity" : 0.1,
# 	"Parasite_Switch_Type" : "RATE_PER_PARASITE_7VARS",
# 	"Population_Density_C50" : 30,
# 	"Population_Density_Infectivity_Correction" : "CONSTANT_INFECTIVITY",
# 	"Infectivity_Scale_Type" : "CONSTANT_INFECTIVITY",
# 	"Population_Scale_Type" : "FIXED_SCALING",
# 	"Post_Infection_Acquisition_Multiplier" : 1,
# 	"Post_Infection_Mortality_Multiplier" : 1,
# 	"Post_Infection_Transmission_Multiplier" : 1,
# 	"Pyrogenic_Threshold" : 1000,
# 	"RBC_Destruction_Multiplier" : 1,
# 	"Rainfall_Filename" : "Namawala_single_node_rainfall_daily.bin",
# 	"Rainfall_In_mm_To_Fill_Swamp" : 1000,
# 	"Rainfall_Scale_Factor" : 1,
# 	"Relative_Humidity_Filename" : "Namawala_single_node_relative_humidity_daily.bin",
# 	"Relative_Humidity_Scale_Factor" : 1,
# 	"Relative_Humidity_Variance" : 0.05,
# 	"Report_Coordinator_Event_Recorder" : 0,
# 	"Report_Event_Recorder" : 0,
# 	"Report_Node_Event_Recorder" : 0,
# 	"Report_Surveillance_Event_Recorder" : 0,
# 	"Run_Number" : 1,
# 	"Sample_Rate_0_18mo" : 1,
# 	"Sample_Rate_10_14" : 1,
# 	"Sample_Rate_15_19" : 1,
# 	"Sample_Rate_18mo_4yr" : 1,
# 	"Sample_Rate_20_Plus" : 1,
# 	"Sample_Rate_5_9" : 1,
# 	"Sample_Rate_Birth" : 2,
# 	"Semipermanent_Habitat_Decay_Rate" : 0.01,
# 	"Serialization_Type" : "NONE",
# 	"Simulation_Duration" : 30,
# 	"Simulation_Timestep" : 1,
# 	"Simulation_Type" : "MALARIA_SIM",
# 	"Start_Time" : 0,
# 	"Susceptibility_Initialization_Distribution_Type" : "DISTRIBUTION_OFF",
# 	"Susceptibility_Scale_Type" : "CONSTANT_SUSCEPTIBILITY",
# 	"Symptomatic_Infectious_Offset" : 0,
# 	"Temperature_Dependent_Feeding_Cycle" : "NO_TEMPERATURE_DEPENDENCE",
# 	"Temporary_Habitat_Decay_Factor" : 0.05,
# 	"Transmission_Blocking_Immunity_Decay_Rate" : 0.01,
# 	"Transmission_Blocking_Immunity_Duration_Before_Decay" : 90,
# 	"Vector_Larval_Rainfall_Mortality" : "NONE",
# 	"Vector_Sampling_Type" : "VECTOR_COMPARTMENTS_NUMBER",
# 	"Vector_Species_Names" : [
# 		"arabiensis",
# 		"funestus",
# 		"gambiae"
# 	],
# 	"Vector_Species_Params" : {
# 		"arabiensis" : {
# 			"Acquire_Modifier" : 1,
# 			"Adult_Life_Expectancy" : 30,
# 			"Anthropophily" : 0.95,
# 			"Aquatic_Arrhenius_1" : 8.42e+10,
# 			"Aquatic_Arrhenius_2" : 8328,
# 			"Aquatic_Mortality_Rate" : 0.1,
# 			"Days_Between_Feeds" : 3,
# 			"Egg_Batch_Size" : 100,
# 			"Immature_Duration" : 2,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"GenTransBlocking" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Primaquine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Quinine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 7,
# 			"Drug_Decay_T2" : 7,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"SP" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Indoor_Feeding_Fraction" : 0.5,
# 			"Infected_Arrhenius_1" : 1.17e+11,
# 			"Infected_Arrhenius_2" : 8336,
# 			"Infected_Egg_Batch_Factor" : 0.8,
# 			"Infectious_Human_Feed_Mortality_Factor" : 1.5,
# 			"Larval_Habitat_Types" : {
# 				"TEMPORARY_RAINFALL" : 1.125e+10
# 			},
# 			"Nighttime_Feeding_Fraction" : 1,
# 			"Transmission_Rate" : 1
# 		},
# 		"funestus" : {
# 			"Acquire_Modifier" : 1,
# 			"Adult_Life_Expectancy" : 30,
# 			"Anthropophily" : 0.95,
# 			"Aquatic_Arrhenius_1" : 8.42e+10,
# 			"Aquatic_Arrhenius_2" : 8328,
# 			"Aquatic_Mortality_Rate" : 0.1,
# 			"Days_Between_Feeds" : 3,
# 			"Egg_Batch_Size" : 100,
# 			"Immature_Duration" : 2,
# 			"Indoor_Feeding_Fraction" : 1,
# 			"Infected_Arrhenius_1" : 1.17e+11,
# 			"Infected_Arrhenius_2" : 8336,
# 			"Infected_Egg_Batch_Factor" : 0.8,
# 			"Infectious_Human_Feed_Mortality_Factor" : 1.5,
# 			"Larval_Habitat_Types" : {
# 				"WATER_VEGETATION" : 6e+08
# 			},
# 			"Nighttime_Feeding_Fraction" : 1,
# 			"Transmission_Rate" : 1
# 		},
# 		"gambiae" : {
# 			"Acquire_Modifier" : 1,
# 			"Adult_Life_Expectancy" : 30,
# 			"Anthropophily" : 0.95,
# 			"Aquatic_Arrhenius_1" : 8.42e+10,
# 			"Aquatic_Arrhenius_2" : 8328,
# 			"Aquatic_Mortality_Rate" : 0.1,
# 			"Days_Between_Feeds" : 3,
# 			"Egg_Batch_Size" : 100,
# 			"Immature_Duration" : 2,
# 			"Indoor_Feeding_Fraction" : 1,
# 			"Infected_Arrhenius_1" : 1.17e+11,
# 			"Infected_Arrhenius_2" : 8336,
# 			"Infected_Egg_Batch_Factor" : 0.8,
# 			"Infectious_Human_Feed_Mortality_Factor" : 1.5,
# 			"Larval_Habitat_Types" : {
# 				"TEMPORARY_RAINFALL" : 1.25e+09
# 			},
# 			"Nighttime_Feeding_Fraction" : 1,
# 			"Transmission_Rate" : 1
# 		}
# 	},
# 	"Vector_Sugar_Feeding_Frequency" : "VECTOR_SUGAR_FEEDING_NONE",
# 	"Wolbachia_Infection_Modification" : 1,
# 	"Wolbachia_Mortality_Modification" : 1,
# 	"x_Base_Population" : 1,
# 	"x_Birth" : 1,
# 	"x_Other_Mortality" : 1,
# 	"x_Temporary_Larval_Habitat" : 1
# }
# Caught exception msg below:
# Expected STRING
#
# /Eradication() [0xa3d233]
# /Eradication(_ZN6Kernel17DetailedExceptionC1EPKciS2_+0x2e7) [0xa3dd87]
# /Eradication(_ZN6Kernel30JsonTypeConfigurationExceptionC2EPKciS2_S2_RKN4json16QuickInterpreterES2_+0x47) [0xa46fb7]
# /Eradication(_Z17GET_CONFIG_STRINGPKN4json16QuickInterpreterEPKc+0x3ab) [0xa05a2b]
# /Eradication(_ZN6Kernel16JsonConfigurable10initConfigINS_22MaternalAntibodiesType4EnumEEEbPKcRT_PKN4json16QuickInterpreterERKNS_18MetadataDescriptor4EnumES5_S5_+0x2c2) [0x78fd22]
# /Eradication(_ZN6Kernel27SusceptibilityMalariaConfig9ConfigureEPK13Configuration+0x827) [0x78d247]
# /Eradication(_ZN6Kernel22IndividualHumanMalaria24InitializeStaticsMalariaEPK13Configuration+0x5f) [0x7bb89f]
# /Eradication(_ZN6Kernel17SimulationMalaria16CreateSimulationEPK13Configuration+0x2f) [0x72b1cf]
# /Eradication(_ZN6Kernel17SimulationFactory16CreateSimulationEv+0x47f) [0x6b91ef]
# /Eradication(_ZN17DefaultController16execute_internalEv+0x7c) [0x92a9fc]
# /Eradication(_Z21ControllerInitWrapperiPPcPN6IdmMpi16MessageInterfaceE+0x1a14) [0x9e2e94]
# /Eradication(_Z14MPIInitWrapperiPPc+0x24) [0x9e4c74]
# /Eradication(main+0x372) [0x609bf2]
# /lib64/libc.so.6(__libc_start_main+0xf5) [0x7fb97b9fe495]
# /Eradication() [0x60e54e]
#
# application called MPI_Abort(MPI_COMM_WORLD, -1) - process 0
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Tafenoquine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		}
# 	},
# 	"Malaria_Model" : "MALARIA_MECHANISTIC_MODEL",
# 	"Malaria_Strain_Model" : "FALCIPARUM_RANDOM_STRAIN",
# 	"Maternal_Infection_Transmission_Probability" : 0,
# 	"Max_Individual_Infections" : 5,
# 	"Max_MSP1_Antibody_Growthrate" : 0.02,
# 	"Max_Node_Population_Samples" : 40,
# 	"Mean_Egg_Hatch_Delay" : 0,
# 	"Mean_Sporozoites_Per_Bite" : 110,
# 	"Memory_Usage_Halting_Threshold_Working_Set_MB" : 4000,
# 	"Memory_Usage_Warning_Threshold_Working_Set_MB" : 3500,
# 	"Merozoites_Per_Hepatocyte" : 15000,
# 	"Merozoites_Per_Schizont" : 16,
# 	"Migration_Model" : "NO_MIGRATION",
# 	"Min_Adapted_Response" : 0.01,
# 	"Min_Days_Between_Clinical_Incidents" : 3,
# 	"Minimum_Adult_Age_Years" : 15,
# 	"Mortality_Blocking_Immunity_Decay_Rate" : 0.001,
# 	"Mortality_Blocking_Immunity_Duration_Before_Decay" : 90,
# 	"Mortality_Time_Course" : "DAILY_MORTALITY",
# 	"Mosquito_Weight" : 1,
# 	"New_Diagnostic_Sensitivity" : 0.01,
# 	"Node_Grid_Size" : 0.042,
# 	"Nonspecific_Antibody_Growth_Rate_Factor" : 0.5,
# 	"Nonspecific_Antigenicity_Factor" : 0.3,
# 	"Num_Cores" : 1,
# 	"Number_Basestrains" : 1,
# 	"Number_Of_Asexual_Cycles_Without_Gametocytes" : 1,
# 	"PKPD_Model" : "FIXED_DURATION_CONSTANT_EFFECT",
# 	"Parasite_Mortality_Inverse_Width" : 10,
# 	"Parasite_Mortality_Threshold" : 2e+06,
# 	"Parasite_Severe_Inverse_Width" : 10,
# 	"Parasite_Severe_Threshold" : 1e+06,
# 	"Parasite_Smear_Sensitivity" : 0.1,
# 	"Parasite_Switch_Type" : "RATE_PER_PARASITE_7VARS",
# 	"Population_Density_C50" : 30,
# 	"Population_Density_Infectivity_Correction" : "CONSTANT_INFECTIVITY",
# 	"Infectivity_Scale_Type" : "CONSTANT_INFECTIVITY",
# 	"Population_Scale_Type" : "FIXED_SCALING",
# 	"Post_Infection_Acquisition_Multiplier" : 1,
# 	"Post_Infection_Mortality_Multiplier" : 1,
# 	"Post_Infection_Transmission_Multiplier" : 1,
# 	"Pyrogenic_Threshold" : 1000,
# 	"RBC_Destruction_Multiplier" : 1,
# 	"Rainfall_Filename" : "Namawala_single_node_rainfall_daily.bin",
# 	"Rainfall_In_mm_To_Fill_Swamp" : 1000,
# 	"Rainfall_Scale_Factor" : 1,
# 	"Relative_Humidity_Filename" : "Namawala_single_node_relative_humidity_daily.bin",
# 	"Relative_Humidity_Scale_Factor" : 1,
# 	"Relative_Humidity_Variance" : 0.05,
# 	"Report_Coordinator_Event_Recorder" : 0,
# 	"Report_Event_Recorder" : 0,
# 	"Report_Node_Event_Recorder" : 0,
# 	"Report_Surveillance_Event_Recorder" : 0,
# 	"Run_Number" : 1,
# 	"Sample_Rate_0_18mo" : 1,
# 	"Sample_Rate_10_14" : 1,
# 	"Sample_Rate_15_19" : 1,
# 	"Sample_Rate_18mo_4yr" : 1,
# 	"Sample_Rate_20_Plus" : 1,
# 	"Sample_Rate_5_9" : 1,
# 	"Sample_Rate_Birth" : 2,
# 	"Semipermanent_Habitat_Decay_Rate" : 0.01,
# 	"Serialization_Type" : "NONE",
# 	"Simulation_Duration" : 30,
# 	"Simulation_Timestep" : 1,
# 	"Simulation_Type" : "MALARIA_SIM",
# 	"Start_Time" : 0,
# 	"Susceptibility_Initialization_Distribution_Type" : "DISTRIBUTION_OFF",
# 	"Susceptibility_Scale_Type" : "CONSTANT_SUSCEPTIBILITY",
# 	"Symptomatic_Infectious_Offset" : 0,
# 	"Temperature_Dependent_Feeding_Cycle" : "NO_TEMPERATURE_DEPENDENCE",
# 	"Temporary_Habitat_Decay_Factor" : 0.05,
# 	"Transmission_Blocking_Immunity_Decay_Rate" : 0.01,
# 	"Transmission_Blocking_Immunity_Duration_Before_Decay" : 90,
# 	"Vector_Larval_Rainfall_Mortality" : "NONE",
# 	"Vector_Sampling_Type" : "VECTOR_COMPARTMENTS_NUMBER",
# 	"Vector_Species_Names" : [
# 		"arabiensis",
# 		"funestus",
# 		"gambiae"
# 	],
# 	"Vector_Species_Params" : {
# 		"arabiensis" : {
# 			"Acquire_Modifier" : 1,
# 			"Adult_Life_Expectancy" : 30,
# 			"Anthropophily" : 0.95,
# 			"Aquatic_Arrhenius_1" : 8.42e+10,
# 			"Aquatic_Arrhenius_2" : 8328,
# 			"Aquatic_Mortality_Rate" : 0.1,
# 			"Days_Between_Feeds" : 3,
# 			"Egg_Batch_Size" : 100,
# 			"Immature_Duration" : 2,
# 			"Indoor_Feeding_Fraction" : 0.5,
# 			"Infected_Arrhenius_1" : 1.17e+11,
# 			"Infected_Arrhenius_2" : 8336,
# 			"Infected_Egg_Batch_Factor" : 0.8,
# 			"Infectious_Human_Feed_Mortality_Factor" : 1.5,
# 			"Larval_Habitat_Types" : {
# 				"TEMPORARY_RAINFALL" : 1.125e+10
# 			},
# 			"Nighttime_Feeding_Fraction" : 1,
# 			"Transmission_Rate" : 1
# 		},
# 		"funestus" : {
# 			"Acquire_Modifier" : 1,
# 			"Adult_Life_Expectancy" : 30,
# 			"Anthropophily" : 0.95,
# 			"Aquatic_Arrhenius_1" : 8.42e+10,
# 			"Aquatic_Arrhenius_2" : 8328,
# 			"Aquatic_Mortality_Rate" : 0.1,
# 			"Days_Between_Feeds" : 3,
# 			"Egg_Batch_Size" : 100,
# 			"Immature_Duration" : 2,
# 			"Indoor_Feeding_Fraction" : 1,
# 			"Infected_Arrhenius_1" : 1.17e+11,
# 			"Infected_Arrhenius_2" : 8336,
# 			"Infected_Egg_Batch_Factor" : 0.8,
# 			"Infectious_Human_Feed_Mortality_Factor" : 1.5,
# 			"Larval_Habitat_Types" : {
# 				"WATER_VEGETATION" : 6e+08
# 			},
# 			"Nighttime_Feeding_Fraction" : 1,
# 			"Transmission_Rate" : 1
# 		},
# 		"gambiae" : {
# 			"Acquire_Modifier" : 1,
# 			"Adult_Life_Expectancy" : 30,
# 			"Anthropophily" : 0.95,
# 			"Aquatic_Arrhenius_1" : 8.42e+10,
# 			"Aquatic_Arrhenius_2" : 8328,
# 			"Aquatic_Mortality_Rate" : 0.1,
# 			"Days_Between_Feeds" : 3,
# 			"Egg_Batch_Size" : 100,
# 			"Immature_Duration" : 2,
# 			"Indoor_Feeding_Fraction" : 1,
# 			"Infected_Arrhenius_1" : 1.17e+11,
# 			"Infected_Arrhenius_2" : 8336,
# 			"Infected_Egg_Batch_Factor" : 0.8,
# 			"Infectious_Human_Feed_Mortality_Factor" : 1.5,
# 			"Larval_Habitat_Types" : {
# 				"TEMPORARY_RAINFALL" : 1.25e+09
# 			},
# 			"Nighttime_Feeding_Fraction" : 1,
# 			"Transmission_Rate" : 1
# 		}
# 	},
# 	"Vector_Sugar_Feeding_Frequency" : "VECTOR_SUGAR_FEEDING_NONE",
# 	"Wolbachia_Infection_Modification" : 1,
# 	"Wolbachia_Mortality_Modification" : 1,
# 	"x_Base_Population" : 1,
# 	"x_Birth" : 1,
# 	"x_Other_Mortality" : 1,
# 	"x_Temporary_Larval_Habitat" : 1
# }
# Caught exception msg below:
# Expected STRING
#
# /Eradication() [0xa3d233]
# /Eradication(_ZN6Kernel17DetailedExceptionC1EPKciS2_+0x2e7) [0xa3dd87]
# /Eradication(_ZN6Kernel30JsonTypeConfigurationExceptionC2EPKciS2_S2_RKN4json16QuickInterpreterES2_+0x47) [0xa46fb7]
# /Eradication(_Z17GET_CONFIG_STRINGPKN4json16QuickInterpreterEPKc+0x3ab) [0xa05a2b]
# /Eradication(_ZN6Kernel16JsonConfigurable10initConfigINS_22MaternalAntibodiesType4EnumEEEbPKcRT_PKN4json16QuickInterpreterERKNS_18MetadataDescriptor4EnumES5_S5_+0x2c2) [0x78fd22]
# /Eradication(_ZN6Kernel27SusceptibilityMalariaConfig9ConfigureEPK13Configuration+0x827) [0x78d247]
# /Eradication(_ZN6Kernel22IndividualHumanMalaria24InitializeStaticsMalariaEPK13Configuration+0x5f) [0x7bb89f]
# /Eradication(_ZN6Kernel17SimulationMalaria16CreateSimulationEPK13Configuration+0x2f) [0x72b1cf]
# /Eradication(_ZN6Kernel17SimulationFactory16CreateSimulationEv+0x47f) [0x6b91ef]
# /Eradication(_ZN17DefaultController16execute_internalEv+0x7c) [0x92a9fc]
# /Eradication(_Z21ControllerInitWrapperiPPcPN6IdmMpi16MessageInterfaceE+0x1a14) [0x9e2e94]
# /Eradication(_Z14MPIInitWrapperiPPc+0x24) [0x9e4c74]
# /Eradication(main+0x372) [0x609bf2]
# /lib64/libc.so.6(__libc_start_main+0xf5) [0x7fb97b9fe495]
# /Eradication() [0x60e54e]
#
#
#
#               Infected => 138 EIR => 0 Infection Rate => 0
#
# REWARD -138
# ACTION {'IRS': array([0.], dtype=float32), 'ITNS': array([0.689186], dtype=float32)}
# Setting IRS to 0.0
# Setting ITNS to 0.6891859769821167
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ray_results/A3C/A3C_MalariaEnvironment_52880_00000_0_2023-06-07_12-26-04
# 2023-06-07 12:26:38,987	INFO trainable.py:172 -- Trainable.setup took 34.177 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2023-06-07 12:26:38,993	WARNING util.py:66 -- Install gputil for GPU system monitoring.
# :actor_name:A3C
# :actor_name:A3C
# 2023-06-07 12:26:44,954	WARNING agent_collector.py:155 -- Provided tensor
# [-1.1622524  0.3783719]
#  does not match space of view requirements actions.
# Provided tensor has shape (2,) and view requirement has shape shape None.Make sure dimensions match to resolve this warning.
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [E] [Eradication]
#
# JsonTypeConfigurationException:
# Exception in utils/Configuration.cpp at 630 in GET_CONFIG_STRING.
# While trying to parse json data for param/key >>> Maternal_Antibodies_Type <<< in otherwise valid json segment...
# {
# 00:00:00 [0] [E] [Eradication]
#
# 	"Acquisition_Blocking_Immunity_Decay_Rate" : 0.01,
# 	"Acquisition_Blocking_Immunity_Duration_Before_Decay" : 90,
# JsonTypeConfigurationException:
# Exception in utils/Configuration.cpp at 630 in GET_CONFIG_STRING.
# 	"Age_Dependent_Biting_Risk_Type" : "OFF",
# 	"Age_Initialization_Distribution_Type" : "DISTRIBUTION_SIMPLE",
# While trying to parse json data for param/key >>> Maternal_Antibodies_Type <<< in otherwise valid json segment...
# {
# 	"Air_Temperature_Filename" : "Namawala_single_node_air_temperature_daily.bin",
# 	"Air_Temperature_Offset" : 0,
# 	"Acquisition_Blocking_Immunity_Decay_Rate" : 0.01,
# 	"Acquisition_Blocking_Immunity_Duration_Before_Decay" : 90,
# 	"Air_Temperature_Variance" : 2,
# 	"Anemia_Mortality_Inverse_Width" : 20,
# 	"Age_Dependent_Biting_Risk_Type" : "OFF",
# 	"Age_Initialization_Distribution_Type" : "DISTRIBUTION_SIMPLE",
# 	"Anemia_Mortality_Threshold" : 1.5,
# 	"Anemia_Severe_Inverse_Width" : 20,
# 	"Air_Temperature_Filename" : "Namawala_single_node_air_temperature_daily.bin",
# 	"Air_Temperature_Offset" : 0,
# 	"Anemia_Severe_Threshold" : 3,
# 	"Antibody_CSP_Decay_Days" : 90,
# 	"Air_Temperature_Variance" : 2,
# 	"Anemia_Mortality_Inverse_Width" : 20,
# 	"Antibody_CSP_Killing_Inverse_Width" : 1.5,
# 	"Antibody_CSP_Killing_Threshold" : 20,
# 	"Antibody_Capacity_Growth_Rate" : 0.1,
# 	"Anemia_Mortality_Threshold" : 1.5,
# 	"Anemia_Severe_Inverse_Width" : 20,
# 	"Anemia_Severe_Threshold" : 3,
# 	"Antibody_CSP_Decay_Days" : 90,
# 	"Antibody_CSP_Killing_Inverse_Width" : 1.5,
# 	"Antibody_CSP_Killing_Threshold" : 20,
# 	"Antibody_Capacity_Growth_Rate" : 0.1,
# 	"Antibody_IRBC_Kill_Rate" : 1.5,
# 	"Antibody_Memory_Level" : 0.225,
# 	"Antibody_Stimulation_C50" : 10,
# 	"Antigen_Switch_Rate" : 2e-09,
# 	"Base_Air_Temperature" : 22,
# 	"Base_Gametocyte_Fraction_Male" : 0.2,
# 	"Base_Gametocyte_Mosquito_Survival_Rate" : 0.01,
# 	"Base_Gametocyte_Production_Rate" : 0.02,
# 	"Base_Individual_Sample_Rate" : 1,
# 	"Base_Land_Temperature" : 26,
# 	"Base_Mortality" : 0,
# 	"Base_Rainfall" : 10,
# 	"Base_Relative_Humidity" : 0.75,
# 	"Base_Sporozoite_Survival_Fraction" : 0.25,
# 	"Antibody_IRBC_Kill_Rate" : 1.5,
# 	"Antibody_Memory_Level" : 0.225,
# 	"Antibody_Stimulation_C50" : 10,
# 	"Antigen_Switch_Rate" : 2e-09,
# 	"Base_Air_Temperature" : 22,
# 	"Base_Gametocyte_Fraction_Male" : 0.2,
# 	"Base_Gametocyte_Mosquito_Survival_Rate" : 0.01,
# 	"Base_Gametocyte_Production_Rate" : 0.02,
# 	"Base_Individual_Sample_Rate" : 1,
# 	"Base_Land_Temperature" : 26,
# 	"Base_Mortality" : 0,
# 	"Base_Rainfall" : 10,
# 	"Birth_Rate_Dependence" : "POPULATION_DEP_RATE",
# 	"Birth_Rate_Time_Dependence" : "NONE",
# 	"Campaign_Filename" : "campaign.json",
# 	"Climate_Model" : "CLIMATE_BY_DATA",
# 	"Climate_Update_Resolution" : "CLIMATE_UPDATE_DAY",
# 	"Clinical_Fever_Threshold_High" : 1,
# 	"Clinical_Fever_Threshold_Low" : 0.5,
# 	"Config_Name" : "Full_Malaria_Model",
# 	"Custom_Coordinator_Events" : [],
# 	"Custom_Individual_Events" : [],
# 	"Custom_Node_Events" : [],
# 	"Custom_Reports_Filename" : "",
# 	"Cytokine_Gametocyte_Inactivation" : 0.05,
# 	"Death_Rate_Dependence" : "NONDISEASE_MORTALITY_BY_AGE_AND_GENDER",
# 	"Default_Geography_Initial_Node_Population" : 1e+06,
# 	"Default_Geography_Torus_Size" : 10,
# 	"Demographics_Filenames" : [
# 		"Namawala_single_node_demographics.json"
# 	],
# 	"Egg_Hatch_Delay_Distribution" : "NO_DELAY",
# 	"Egg_Hatch_Density_Dependence" : "NO_DENSITY_DEPENDENCE",
# 	"Base_Relative_Humidity" : 0.75,
# 	"Base_Sporozoite_Survival_Fraction" : 0.25,
# 	"Birth_Rate_Dependence" : "POPULATION_DEP_RATE",
# 	"Birth_Rate_Time_Dependence" : "NONE",
# 	"Campaign_Filename" : "campaign.json",
# 	"Climate_Model" : "CLIMATE_BY_DATA",
# 	"Climate_Update_Resolution" : "CLIMATE_UPDATE_DAY",
# 	"Clinical_Fever_Threshold_High" : 1,
# 	"Clinical_Fever_Threshold_Low" : 0.5,
# 	"Config_Name" : "Full_Malaria_Model",
# 	"Custom_Coordinator_Events" : [],
# 	"Custom_Individual_Events" : [],
# 	"Egg_Saturation_At_Oviposition" : "SATURATION_AT_OVIPOSITION",
# 	"Enable_Aging" : 1,
# 	"Enable_Birth" : 1,
# 	"Enable_Climate_Stochasticity" : 1,
# 	"Enable_Default_Reporting" : 1,
# 	"Enable_Demographics_Birth" : 1,
# 	"Enable_Demographics_Builtin" : 0,
# 	"Enable_Demographics_Reporting" : 1,
# 	"Enable_Demographics_Risk" : 1,
# 	"Enable_Disease_Mortality" : 1,
# 	"Custom_Node_Events" : [],
# 	"Enable_Drought_Egg_Hatch_Delay" : 0,
# 	"Enable_Egg_Mortality" : 0,
# 	"Enable_Heterogeneous_Intranode_Transmission" : 0,
# 	"Enable_Infectivity_Reservoir" : 0,
# 	"Enable_Initial_Prevalence" : 1,
# 	"Enable_Initial_Susceptibility_Distribution" : 0,
# 	"Enable_Interventions" : 1,
# 	"Enable_Maternal_Antibodies_Transmission" : 1,
# 	"Enable_Maternal_Infection_Transmission" : 1,
# 	"Enable_Maternal_Protection" : 1,
# 	"Enable_Natural_Mortality" : 1,
# 	"Enable_Property_Output" : 0,
# 	"Enable_Rainfall_Stochasticity" : 1,
# 	"Enable_Sexual_Combination" : 0,
# 	"Enable_Spatial_Output" : 0,
# 	"Enable_Superinfection" : 1,
# 	"Enable_Susceptibility_Scaling" : 0,
# 	"Enable_Temperature_Dependent_Egg_Hatching" : 0,
# 	"Enable_Termination_On_Zero_Total_Infectivity" : 0,
# 	"Enable_Vector_Aging" : 0,
# 	"Enable_Vector_Migration" : 0,
# 	"Enable_Vector_Mortality" : 1,
# 	"Enable_Vital_Dynamics" : 1,
# 	"Erythropoiesis_Anemia_Effect" : 0,
# 	"Falciparum_MSP_Variants" : 4,
# 	"Custom_Reports_Filename" : "",
# 	"Cytokine_Gametocyte_Inactivation" : 0.05,
# 	"Death_Rate_Dependence" : "NONDISEASE_MORTALITY_BY_AGE_AND_GENDER",
# 	"Default_Geography_Initial_Node_Population" : 1e+06,
# 	"Default_Geography_Torus_Size" : 10,
# 	"Demographics_Filenames" : [
# 		"Namawala_single_node_demographics.json"
# 	],
# 	"Egg_Hatch_Delay_Distribution" : "NO_DELAY",
# 	"Egg_Hatch_Density_Dependence" : "NO_DENSITY_DEPENDENCE",
# 	"Egg_Saturation_At_Oviposition" : "SATURATION_AT_OVIPOSITION",
# 	"Enable_Aging" : 1,
# 	"Enable_Birth" : 1,
# 	"Enable_Climate_Stochasticity" : 1,
# 	"Falciparum_Nonspecific_Types" : 4,
# 	"Falciparum_PfEMP1_Variants" : 300,
# 	"Fever_Detection_Threshold" : 1,
# 	"Fever_IRBC_Kill_Rate" : 1,
# 	"Fever_Mortality_Inverse_Width" : 10,
# 	"Fever_Mortality_Threshold" : 3,
# 	"Fever_Severe_Inverse_Width" : 10,
# 	"Fever_Severe_Threshold" : 1.5,
# 	"Gametocyte_Stage_Survival_Rate" : 1,
# 	"Genome_Markers" : [],
# 	"HEG_Fecundity_Limiting" : 0,
# 	"HEG_Homing_Rate" : 0,
# 	"HEG_Model" : "OFF",
# 	"Human_Feeding_Mortality" : 1,
# 	"Incubation_Period_Constant" : 7,
# 	"Incubation_Period_Distribution" : "CONSTANT_DISTRIBUTION",
# 	"Individual_Sampling_Type" : "TRACK_ALL",
# 	"Infection_Updates_Per_Timestep" : 24,
# 	"Innate_Immune_Variation_Type" : "NONE",
# 	"Koppen_Filename" : "",
# 	"Land_Temperature_Filename" : "Namawala_single_node_land_temperature_daily.bin",
# 	"Land_Temperature_Offset" : 0,
# 	"Land_Temperature_Variance" : 2,
# 	"Enable_Default_Reporting" : 1,
# 	"Enable_Demographics_Birth" : 1,
# 	"Enable_Demographics_Builtin" : 0,
# 	"Enable_Demographics_Reporting" : 1,
# 	"Enable_Demographics_Risk" : 1,
# 	"Enable_Disease_Mortality" : 1,
# 	"Enable_Drought_Egg_Hatch_Delay" : 0,
# 	"Enable_Egg_Mortality" : 0,
# 	"Enable_Heterogeneous_Intranode_Transmission" : 0,
# 	"Enable_Infectivity_Reservoir" : 0,
# 	"Enable_Initial_Prevalence" : 1,
# 	"Enable_Initial_Susceptibility_Distribution" : 0,
# 	"Enable_Interventions" : 1,
# 	"Enable_Maternal_Antibodies_Transmission" : 1,
# 	"Enable_Maternal_Infection_Transmission" : 1,
# 	"Enable_Maternal_Protection" : 1,
# 	"Enable_Natural_Mortality" : 1,
# 	"Enable_Property_Output" : 0,
# 	"Enable_Rainfall_Stochasticity" : 1,
# 	"Enable_Sexual_Combination" : 0,
# 	"Enable_Spatial_Output" : 0,
# 	"Enable_Superinfection" : 1,
# 	"Enable_Susceptibility_Scaling" : 0,
# 	"Enable_Temperature_Dependent_Egg_Hatching" : 0,
# 	"Enable_Termination_On_Zero_Total_Infectivity" : 0,
# 	"Enable_Vector_Aging" : 0,
# 	"Enable_Vector_Migration" : 0,
# 	"Enable_Vector_Mortality" : 1,
# 	"Enable_Vital_Dynamics" : 1,
# 	"Erythropoiesis_Anemia_Effect" : 0,
# 	"Falciparum_MSP_Variants" : 4,
# 	"Falciparum_Nonspecific_Types" : 4,
# 	"Falciparum_PfEMP1_Variants" : 300,
# 	"Fever_Detection_Threshold" : 1,
# 	"Fever_IRBC_Kill_Rate" : 1,
# 	"Fever_Mortality_Inverse_Width" : 10,
# 	"Fever_Mortality_Threshold" : 3,
# 	"Fever_Severe_Inverse_Width" : 10,
# 	"Fever_Severe_Threshold" : 1.5,
# 	"Gametocyte_Stage_Survival_Rate" : 1,
# 	"Genome_Markers" : [],
# 	"HEG_Fecundity_Limiting" : 0,
# 	"HEG_Homing_Rate" : 0,
# 	"HEG_Model" : "OFF",
# 	"Human_Feeding_Mortality" : 1,
# 	"Incubation_Period_Constant" : 7,
# 	"Incubation_Period_Distribution" : "CONSTANT_DISTRIBUTION",
# 	"Larval_Density_Dependence" : "UNIFORM_WHEN_OVERPOPULATION",
# 	"Load_Balance_Filename" : "",
# 	"MSP1_Merozoite_Kill_Fraction" : 1,
# 	"Malaria_Drug_Params" : {
# 		"Artemether_Lumefantrine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 	"Individual_Sampling_Type" : "TRACK_ALL",
# 	"Infection_Updates_Per_Timestep" : 24,
# 	"Innate_Immune_Variation_Type" : "NONE",
# 	"Koppen_Filename" : "",
# 	"Land_Temperature_Filename" : "Namawala_single_node_land_temperature_daily.bin",
# 	"Land_Temperature_Offset" : 0,
# 	"Land_Temperature_Variance" : 2,
# 	"Larval_Density_Dependence" : "UNIFORM_WHEN_OVERPOPULATION",
# 	"Load_Balance_Filename" : "",
# 	"MSP1_Merozoite_Kill_Fraction" : 1,
# 	"Malaria_Drug_Params" : {
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Artemisinin" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Chloroquine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 4,
# 			"Drug_Decay_T2" : 15,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 		"Artemether_Lumefantrine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Vd" : 3,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"GenPreerythrocytic" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"GenTransBlocking" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Artemisinin" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Primaquine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 10,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"Quinine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 7,
# 		"Chloroquine" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 4,
# 			"Drug_Decay_T2" : 15,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Gametocyte02_Killrate" : 0,
# 			"Drug_Gametocyte34_Killrate" : 0,
# 			"Drug_GametocyteM_Killrate" : 0,
# 			"Drug_Hepatocyte_Killrate" : 0,
# 			"Drug_PKPD_C50" : 100,
# 			"Drug_Vd" : 3,
# 			"Max_Drug_IRBC_Kill" : 0
# 		},
# 		"GenPreerythrocytic" : {
# 			"Bodyweight_Exponent" : 0,
# 			"Drug_Cmax" : 1000,
# 			"Drug_Decay_T1" : 1,
# 			"Drug_Decay_T2" : 1,
# 			"Drug_Dose_Interval" : 1,
# 			"Drug_Fulltreatment_Doses" : 3,
# 			"Drug_Decay_T2" : 7,
# 			"Drug_Dose_Interval" : 1,
# ...
# 00:00:01 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 222 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 283 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 231 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 248 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 238 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 251 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 217 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 256 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 264 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 254 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 232 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 235 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 240 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 244 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 263 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 222 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:02 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:02 [0] [I] [Controller] Exiting execute_internal
# 00:00:02 [0] [I] [Eradication] Controller executed successfully.
#
#
#               Infected => 138 EIR => 0 Infection Rate => 0
#
# REWARD -138
# ACTION {'IRS': array([0.675921], dtype=float32), 'ITNS': array([0.25016725], dtype=float32)}
# Setting IRS to 0.6759210228919983
# Setting ITNS to 0.25016725063323975
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ray_results/A3C/A3C_MalariaEnvironment_52880_00000_0_2023-06-07_12-26-04
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:00 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:00 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:00 [0] [I] [Simulation] Merging node rank maps...
# 00:00:00 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:00 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 664 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 242 'SimpleBednet' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 669 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 658 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 672 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 704 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 668 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 673 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 653 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 667 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 705 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 670 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 686 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 682 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 651 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 711 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 651 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 676 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 683 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 671 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 649 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 697 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 680 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 707 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 656 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 655 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 660 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 690 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 669 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 693 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:02 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:02 [0] [I] [Controller] Exiting execute_internal
# 00:00:02 [0] [I] [Eradication] Controller executed successfully.
#
#
#               Infected => 138 EIR => 0 Infection Rate => 0
#
# REWARD -138
# ACTION {'IRS': array([0.29107243], dtype=float32), 'ITNS': array([0.44235188], dtype=float32)}
# Setting IRS to 0.29107242822647095
# Setting ITNS to 0.4423518776893616
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ray_results/A3C/A3C_MalariaEnvironment_52880_00000_0_2023-06-07_12-26-04

# %%
algo.train()
# Out:
# ACTION {'IRS': array([0.48402694], dtype=float32), 'ITNS': array([1.], dtype=float32)}
# Setting IRS to 0.4840269386768341
# Setting ITNS to 1.0
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# ACTION {'IRS': array([0.14114097], dtype=float32), 'ITNS': array([0.], dtype=float32)}
# Setting IRS to 0.14114096760749817
# Setting ITNS to 0.0
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:00 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:00 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:00 [0] [I] [Simulation] Merging node rank maps...
# 00:00:00 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:00 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 126 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'SimpleBednet' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 137 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 131 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 169 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 153 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 154 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 134 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 161 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 160 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 118 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 147 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 136 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 126 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 132 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 139 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 154 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 149 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 132 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 133 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 149 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 149 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 149 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 140 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 147 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 131 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 147 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 133 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 144 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 141 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Controller] Exiting execute_internal
# 00:00:01 [0] [I] [Eradication] Controller executed successfully.
#
# REWARD 0
# ACTION {'IRS': array([0.346887], dtype=float32), 'ITNS': array([0.8953233], dtype=float32)}
# Setting IRS to 0.3468869924545288
# Setting ITNS to 0.8953232765197754
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# 2023-06-05 16:32:57,078	ERROR actor.py:1172 -- Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/utils/actor_manager.py", line 174, in apply
#     return func(self, *args, **kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/algorithms/a3c/a3c.py", line 196, in sample_and_compute_grads
#     samples = worker.sample()
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/evaluation/rollout_worker.py", line 900, in sample
#     batches = [self.input_reader.next()]
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/evaluation/sampler.py", line 92, in next
#     batches = [self.get_data()]
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/evaluation/sampler.py", line 513, in get_data
#     rollout = self.queue.get(timeout=600.0)
#   File "/opt/anaconda3/lib/python3.8/queue.py", line 179, in get
#     self.not_empty.wait(remaining)
#   File "/opt/anaconda3/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1074, in ray._raylet.execute_task_with_cancellation_handler
# AttributeError: 'ray._raylet.CoreWorker' object has no attribute 'actors'
# An unexpected internal error occurred while the worker was executing a task.
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/utils/actor_manager.py", line 174, in apply
#     return func(self, *args, **kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/algorithms/a3c/a3c.py", line 196, in sample_and_compute_grads
#     samples = worker.sample()
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/evaluation/rollout_worker.py", line 900, in sample
#     batches = [self.input_reader.next()]
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/evaluation/sampler.py", line 92, in next
#     batches = [self.get_data()]
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/evaluation/sampler.py", line 513, in get_data
#     rollout = self.queue.get(timeout=600.0)
#   File "/opt/anaconda3/lib/python3.8/queue.py", line 179, in get
#     self.not_empty.wait(remaining)
#   File "/opt/anaconda3/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1074, in ray._raylet.execute_task_with_cancellation_handler
# AttributeError: 'ray._raylet.CoreWorker' object has no attribute 'actors'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1176, in ray._raylet.task_execution_handler
# SystemExit
# 2023-06-05 16:32:57,287	ERROR actor.py:1172 -- Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/utils/actor_manager.py", line 174, in apply
#     return func(self, *args, **kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/algorithms/a3c/a3c.py", line 196, in sample_and_compute_grads
#     samples = worker.sample()
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/evaluation/rollout_worker.py", line 900, in sample
#     batches = [self.input_reader.next()]
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/evaluation/sampler.py", line 92, in next
#     batches = [self.get_data()]
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/evaluation/sampler.py", line 513, in get_data
#     rollout = self.queue.get(timeout=600.0)
#   File "/opt/anaconda3/lib/python3.8/queue.py", line 179, in get
#     self.not_empty.wait(remaining)
#   File "/opt/anaconda3/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1074, in ray._raylet.execute_task_with_cancellation_handler
# AttributeError: 'ray._raylet.CoreWorker' object has no attribute 'actors'
# An unexpected internal error occurred while the worker was executing a task.
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/utils/actor_manager.py", line 174, in apply
#     return func(self, *args, **kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/algorithms/a3c/a3c.py", line 196, in sample_and_compute_grads
#     samples = worker.sample()
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/evaluation/rollout_worker.py", line 900, in sample
#     batches = [self.input_reader.next()]
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/evaluation/sampler.py", line 92, in next
#     batches = [self.get_data()]
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/rllib/evaluation/sampler.py", line 513, in get_data
#     rollout = self.queue.get(timeout=600.0)
#   File "/opt/anaconda3/lib/python3.8/queue.py", line 179, in get
#     self.not_empty.wait(remaining)
#   File "/opt/anaconda3/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1074, in ray._raylet.execute_task_with_cancellation_handler
# AttributeError: 'ray._raylet.CoreWorker' object has no attribute 'actors'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1176, in ray._raylet.task_execution_handler
# SystemExit
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:00 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:00 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:00 [0] [I] [Simulation] Merging node rank maps...
# 00:00:00 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:00 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 126 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'SimpleBednet' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 137 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 131 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 169 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 153 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 154 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 134 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 161 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 160 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 118 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 147 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 136 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 126 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 132 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 139 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 154 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 149 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 132 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 133 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 149 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 149 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 149 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 140 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 147 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 131 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 147 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 133 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 144 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 141 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Controller] Exiting execute_internal
# 00:00:01 [0] [I] [Eradication] Controller executed successfully.
#
# REWARD 0
# ACTION {'IRS': array([0.], dtype=float32), 'ITNS': array([0.7427112], dtype=float32)}
# Setting IRS to 0.0
# Setting ITNS to 0.7427111864089966
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/contextlib.py in helper(*args, **kwds)
#     236             <cleanup>
#     237     """
# --> 238     @wraps(func)
#     239     def helper(*args, **kwds):
#     240         return _GeneratorContextManager(func, args, kwds)
#
# KeyboardInterrupt:
# Exception ignored in: 'ray._raylet.task_execution_handler'
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/contextlib.py", line 238, in helper
#     @wraps(func)
# KeyboardInterrupt:
# /home/mbwie001/ms/MSC_EMOD
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/contextlib.py in helper(*args, **kwds)
#     236             <cleanup>
#     237     """
# --> 238     @wraps(func)
#     239     def helper(*args, **kwds):
#     240         return _GeneratorContextManager(func, args, kwds)
#
# KeyboardInterrupt:
# Exception ignored in: 'ray._raylet.task_execution_handler'
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/contextlib.py", line 238, in helper
#     @wraps(func)
# KeyboardInterrupt:
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:01 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:01 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:01 [0] [I] [Simulation] Merging node rank maps...
# 00:00:01 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:01 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:01 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:01 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:01 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:01 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 126 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'SimpleBednet' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 137 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 131 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 169 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 153 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 154 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 134 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 161 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 160 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 118 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 147 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 136 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 126 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 132 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 139 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 154 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 149 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 132 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 133 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 149 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 149 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 149 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 140 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 147 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 131 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 147 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 133 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 144 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 141 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Controller] Exiting execute_internal
# 00:00:01 [0] [I] [Eradication] Controller executed successfully.
#
# REWARD 0
# ACTION {'IRS': array([0.9669795], dtype=float32), 'ITNS': array([1.], dtype=float32)}
# Setting IRS to 0.9669795036315918
# Setting ITNS to 1.0
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.8/site-packages/ray/_private/client_mode_hook.py in disable_client_hook()
#      62 @contextmanager
#      63 def disable_client_hook():
# ---> 64     val = _disable_client_hook()
#      65     try:
#      66         yield None
#
# ~/.local/lib/python3.8/site-packages/ray/_private/client_mode_hook.py in _disable_client_hook()
#      42 def _disable_client_hook():
#      43     global _client_hook_status_on_thread
# ---> 44     out = _get_client_hook_status_on_thread()
#      45     _client_hook_status_on_thread.status = False
#      46     return out
#
# ~/.local/lib/python3.8/site-packages/ray/_private/client_mode_hook.py in _get_client_hook_status_on_thread()
#      30     """
#      31     global _client_hook_status_on_thread
# ---> 32     if not hasattr(_client_hook_status_on_thread, "status"):
#      33         _client_hook_status_on_thread.status = True
#      34     return _client_hook_status_on_thread.status
#
# KeyboardInterrupt:
# Exception ignored in: 'ray._raylet.task_execution_handler'
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 64, in disable_client_hook
#     val = _disable_client_hook()
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 44, in _disable_client_hook
#     out = _get_client_hook_status_on_thread()
#   File "/home/mbwie001/.local/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 32, in _get_client_hook_status_on_thread
#     if not hasattr(_client_hook_status_on_thread, "status"):
# KeyboardInterrupt:
# /home/mbwie001/ms/MSC_EMOD
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-f38e2f7e52ae> in <module>
# ----> 1 algo.train()
#
# ~/.local/lib/python3.8/site-packages/ray/tune/trainable/trainable.py in train(self)
#     362         start = time.time()
#     363         try:
# --> 364             result = self.step()
#     365         except Exception as e:
#     366             skipped = skip_exceptions(e)
#
# ~/.local/lib/python3.8/site-packages/ray/rllib/algorithms/algorithm.py in step(self)
#     747         #   evaluate after the training iteration is entirely done.
#     748         else:
# ...
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 275 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 261 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 258 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 261 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 299 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 269 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 272 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 273 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 278 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 298 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 281 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 269 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 269 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 257 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 287 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 253 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 282 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 252 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Controller] Exiting execute_internal
# 00:00:01 [0] [I] [Eradication] Controller executed successfully.
#
# REWARD 0
# ACTION {'IRS': array([0.], dtype=float32), 'ITNS': array([0.16921154], dtype=float32)}
# Setting IRS to 0.0
# Setting ITNS to 0.16921153664588928
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:01 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:01 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:01 [0] [I] [Simulation] Merging node rank maps...
# 00:00:01 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:01 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:01 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:01 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:01 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:01 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 257 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1000 'SimpleBednet' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 270 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 277 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 271 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 294 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 269 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 253 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 298 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 294 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 258 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 280 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 275 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 261 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 258 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 261 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 299 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 269 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 272 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 273 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 278 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 298 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 281 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 269 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 269 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 257 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 287 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 253 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 282 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 252 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Controller] Exiting execute_internal
# 00:00:01 [0] [I] [Eradication] Controller executed successfully.
#
# REWARD 0
# ACTION {'IRS': array([0.00435722], dtype=float32), 'ITNS': array([0.4998773], dtype=float32)}
# Setting IRS to 0.0043572187423706055
# Setting ITNS to 0.49987730383872986
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD

# %% [markdown]
# ## Train Manually

# %%
algo = config.build()  
for i in range(1):
    print(f"Iteration Count: {i}")
    algo.train()
# Out:
# :actor_name:RolloutWorker
# ACTION OrderedDict([('IRS', array([0.90205145], dtype=float32)), ('ITNS', array([0.5838243], dtype=float32))])
# Setting IRS to 0.9020514488220215
# Setting ITNS to 0.5838242769241333
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
# :actor_name:RolloutWorker
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:00 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:00 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:00 [0] [I] [Simulation] Merging node rank maps...
# 00:00:00 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:00 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 894 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 597 'SimpleBednet' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 905 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 886 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 893 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 922 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 903 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 908 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 895 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 891 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 911 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 912 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 897 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 905 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 879 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 909 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 907 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 893 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 891 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 893 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 888 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 918 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 908 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 913 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 915 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 902 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 898 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 912 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 895 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 901 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Controller] Exiting execute_internal
# 00:00:01 [0] [I] [Eradication] Controller executed successfully.
#
# REWARD 0
# :actor_name:RolloutWorker
# ACTION OrderedDict([('IRS', array([0.0779113], dtype=float32)), ('ITNS', array([0.39995566], dtype=float32))])
# Setting IRS to 0.07791130244731903
# Setting ITNS to 0.3999556601047516
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
# :actor_name:RolloutWorker
# /home/mbwie001/ms/MSC_EMOD
# ACTION {'IRS': array([1.], dtype=float32), 'ITNS': array([1.], dtype=float32)}
# Setting IRS to 1.0
# Setting ITNS to 1.0
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:00 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:00 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:00 [0] [I] [Simulation] Merging node rank maps...
# 00:00:00 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:00 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1000 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1000 'SimpleBednet' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:00 [0] [I] [Controller] Exiting execute_internal
# 00:00:00 [0] [I] [Eradication] Controller executed successfully.
#
# REWARD 0
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:00 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:00 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:00 [0] [I] [Simulation] Merging node rank maps...
# 00:00:00 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:00 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1000 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1000 'SimpleBednet' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:00 [0] [I] [Controller] Exiting execute_internal
# 00:00:00 [0] [I] [Eradication] Controller executed successfully.
#
# REWARD 0
# ACTION {'IRS': array([1.], dtype=float32), 'ITNS': array([0.17943332], dtype=float32)}
# Setting IRS to 1.0
# Setting ITNS to 0.17943331599235535
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# ACTION {'IRS': array([0.3512864], dtype=float32), 'ITNS': array([0.6114312], dtype=float32)}
# Setting IRS to 0.3512864112854004
# Setting ITNS to 0.6114311814308167
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:00 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:00 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:00 [0] [I] [Simulation] Merging node rank maps...
# 00:00:00 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:00 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:00 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:00 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:00 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1000 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 159 'SimpleBednet' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1000 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1000 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1000 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1000 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1003 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1003 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1003 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1003 Infected: 138
# 00:00:01 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Controller] Exiting execute_internal
# 00:00:01 [0] [I] [Eradication] Controller executed successfully.
#
# REWARD 0
# ACTION {'IRS': array([0.4566362], dtype=float32), 'ITNS': array([0.12135023], dtype=float32)}
# Setting IRS to 0.4566361904144287
# Setting ITNS to 0.1213502287864685
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# 2023-06-05 16:06:56,992	INFO trainable.py:172 -- Trainable.setup took 20.079 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2023-06-05 16:06:56,996	WARNING util.py:66 -- Install gputil for GPU system monitoring.
# Iteration Count: 0
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:00 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:00 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:00 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:00 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:00 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:00 [0] [I] [Simulation] Merging node rank maps...
# 00:00:00 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# ...
# 00:00:00 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 590 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 611 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 571 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 999 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 559 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 578 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 616 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 585 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 585 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 602 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 573 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 608 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 581 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 582 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 601 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 591 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 601 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 584 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 590 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 598 'IRSHousingModification' interventions at node 340461476
# 00:00:00 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:00 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:00 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:00 [0] [I] [Controller] Exiting execute_internal
# 00:00:00 [0] [I] [Eradication] Controller executed successfully.
#
# REWARD 0
# ACTION {'IRS': array([1.], dtype=float32), 'ITNS': array([1.], dtype=float32)}
# Setting IRS to 1.0
# Setting ITNS to 1.0
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 195 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:01 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:01 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:01 [0] [I] [Simulation] Merging node rank maps...
# 00:00:01 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:01 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:01 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:01 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:01 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:01 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1000 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1000 'SimpleBednet' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 1000 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1001 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 1001 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1002 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 1002 Infected: 138
# 00:00:01 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:01 [0] [I] [Controller] Exiting execute_internal
# 00:00:01 [0] [I] [Eradication] Controller executed successfully.
#
# REWARD 0
