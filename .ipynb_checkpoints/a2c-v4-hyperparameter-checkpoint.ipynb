# %%
import os
import sys
# print(sys.path)
module_path = os.path.abspath(os.path.join('.'))
# print(module_path)
if module_path not in sys.path:
    sys.path.append(module_path)
# print(sys.path)

# %% [markdown]
# ## Initiate RAY

# %%
from ray.rllib.algorithms.a3c import A3CConfig
from ray import tune, air
import ray
from env.environment import MalariaEnvironment

# %%
from utils.plot_parameter_utils import *
# Out:
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100007 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 42657 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100014 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100014 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100025 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100025 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100040 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100040 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100051 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100051 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100057 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100057 Infected: 13702
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100070 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100070 Infected: 13702
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100081 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100081 Infected: 13702
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100093 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100093 Infected: 13702
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100104 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100104 Infected: 13702
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100106 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100106 Infected: 13702
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100116 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100116 Infected: 13702
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100127 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100127 Infected: 13702
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100133 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100133 Infected: 13702
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100132 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100132 Infected: 13692
# 00:00:17 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100104 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100104 Infected: 13656
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 99627 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99627 Infected: 13170
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 98921 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98921 Infected: 12452
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 92909 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92909 Infected: 6430
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 89768 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89768 Infected: 3281
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 88154 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88154 Infected: 1660
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 88137 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88137 Infected: 1641
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87855 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87855 Infected: 1351
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87863 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87863 Infected: 1351
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87662 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87662 Infected: 1145
# 00:00:28 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87671 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87671 Infected: 1145
# 00:00:29 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87503 'IRSHousingModification' interventions at node 340461476
# 00:00:29 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87503 Infected: 964
# 00:00:29 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87511 'IRSHousingModification' interventions at node 340461476
# 00:00:30 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87511 Infected: 962
# 00:00:30 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87376 'IRSHousingModification' interventions at node 340461476
# 00:00:31 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87376 Infected: 818
# 00:00:31 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:31 [0] [I] [Controller] Exiting execute_internal
# 00:00:31 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 455.93333333333334
#             Cost => 223.377
#             Mean Parasitemia => 8787.038495794734
#             Disease Deaths => 4822.866666666667
#
# REWARD -232.50433333333334
# ACTION {'IRS': array([0.], dtype=float32), 'ITNS': array([0.20055681], dtype=float32)}
# Setting IRS to 0.0
# Setting ITNS to 0.20055681467056274
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD

# %%
get_init_theta()
# Out:
# array([0.9, 0.9])
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74531 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74202 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100014 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74102 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100018 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74209 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100027 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74057 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74283 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100035 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74288 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100043 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74291 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100052 Infected: 13701
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74142 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100060 Infected: 13701
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74278 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100068 Infected: 13700
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74311 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100080 Infected: 13700
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74286 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13699
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74381 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100087 Infected: 13699
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74180 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100099 Infected: 13699
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74194 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100100 Infected: 13691
# 00:00:17 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74007 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100062 Infected: 13647
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 73722 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99594 Infected: 13166
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 73438 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98859 Infected: 12424
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 68984 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92859 Infected: 6417
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66444 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89692 Infected: 3248
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65502 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88131 Infected: 1680
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65465 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88122 Infected: 1664
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65117 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87847 Infected: 1383
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65432 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87847 Infected: 1383
# 00:00:28 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 64965 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87594 Infected: 1122
# 00:00:28 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65067 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87602 Infected: 1122
# 00:00:29 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65014 'IRSHousingModification' interventions at node 340461476
# 00:00:29 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87424 Infected: 939
# 00:00:29 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 64969 'IRSHousingModification' interventions at node 340461476
# 00:00:30 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87426 Infected: 937
# 00:00:30 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 64705 'IRSHousingModification' interventions at node 340461476
# 00:00:31 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87304 Infected: 801
# 00:00:31 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:31 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:31 [0] [I] [Controller] Exiting execute_internal
# 00:00:31 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.03333333333336
#             Cost => 164.52528
#             Mean Parasitemia => 8805.375244331353
#             Disease Deaths => 4825.933333333333
#
# REWARD -173.65361333333334
# ACTION {'IRS': array([1.], dtype=float32), 'ITNS': array([0.55443746], dtype=float32)}
# Setting IRS to 1.0
# Setting ITNS to 0.5544374585151672
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74531 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74202 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100014 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74102 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100018 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74209 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100027 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74057 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74283 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100035 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74288 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100043 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74291 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100052 Infected: 13701
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74142 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100060 Infected: 13701
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74278 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100068 Infected: 13700
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74311 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100080 Infected: 13700
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74286 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13699
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74381 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100087 Infected: 13699
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74180 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100099 Infected: 13699
# 00:00:17 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74194 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100100 Infected: 13691
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74007 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100062 Infected: 13647
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 73722 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99594 Infected: 13166
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 73438 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98859 Infected: 12424
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 68984 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92859 Infected: 6417
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66444 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89692 Infected: 3248
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65502 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88131 Infected: 1680
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65465 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88122 Infected: 1664
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65117 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87847 Infected: 1383
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65432 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87847 Infected: 1383
# 00:00:28 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 64965 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 
# 00:00:28 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 55142 'IRSHousingModification' interventions at node 340461476
# 00:00:29 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87426 Infected: 937
# 00:00:29 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 54825 'IRSHousingModification' interventions at node 340461476
# 00:00:29 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87304 Infected: 801
# 00:00:29 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:29 [0] [I] [Controller] Exiting execute_internal
# 00:00:29 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.03333333333336
#             Cost => 139.61008
#             Mean Parasitemia => 8805.375244331353
#             Disease Deaths => 4825.933333333333
#
# REWARD -148.73841333333334
# ACTION {'IRS': array([0.2862625], dtype=float32), 'ITNS': array([0.5014666], dtype=float32)}
# Setting IRS to 0.28626251220703125
# Setting ITNS to 0.5014665722846985
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:03 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:03 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:03 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:03 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:03 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:03 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80028 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100007 'SimpleBednet' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79676 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100014 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79749 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100018 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79776 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100027 Infected: 13702
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79678 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79815 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100035 Infected: 13701
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79849 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100043 Infected: 13701
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79680 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100052 Infected: 13701
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79660 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100060 Infected: 13701
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79865 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100068 Infected: 13700
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79888 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100080 Infected: 13700
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79833 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13699
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79890 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100087 Infected: 13699
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79788 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100099 Infected: 13699
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79736 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100100 Infected: 13691
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79543 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100062 Infected: 13647
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79253 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99594 Infected: 13166
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 78813 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98859 Infected: 12424
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74061 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92859 Infected: 6417
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 71387 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89692 Infected: 3248
# 00:00:29 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 70233 'IRSHousingModification' interventions at node 340461476
# 00:00:29 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88131 Infected: 1680
# 00:00:29 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 70374 'IRSHousingModification' interventions at node 340461476
# 00:00:30 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88122 Infected: 1664
# 00:00:30 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 69978 'IRSHousingModification' interventions at node 340461476
# 00:00:31 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87847 Infected: 1383
# 00:00:31 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 70204 'IRSHousingModification' interventions at node 340461476
# 00:00:32 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87847 Infected: 1383
# 00:00:32 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 69717 'IRSHousingModification' interventions at node 340461476
# 00:00:32 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87594 Infected: 1122
# 00:00:33 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 69874 'IRSHousingModification' interventions at node 340461476
# 00:00:33 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87602 Infected: 1122
# 00:00:33 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 69829 'IRSHousingModification' interventions at node 340461476
# 00:00:34 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87424 Infected: 939
# 00:00:34 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 69778 'IRSHousingModification' interventions at node 340461476
# 00:00:34 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87426 Infected: 937
# 00:00:35 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 69518 'IRSHousingModification' interventions at node 340461476
# 00:00:35 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87304 Infected: 801
# 00:00:35 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:35 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:35 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:35 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:35 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:35 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:35 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:35 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:35 [0] [I] [Controller] Exiting execute_internal
# 00:00:35 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.03333333333336
#             Cost => 180.5081
#             Mean Parasitemia => 8805.375244331353
#             Disease Deaths => 4825.933333333333
#
# REWARD -189.63643333333334
# ACTION {'IRS': array([0.44408312], dtype=float32), 'ITNS': array([0.55262357], dtype=float32)}
# Setting IRS to 0.4440831243991852
# Setting ITNS to 0.5526235699653625
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
# /home/mbwie001/ms/MSC_EMOD

# %%
ray.init(ignore_reinit_error=True, num_cpus=10,local_mode=True)
# ray.init()
# Out:
# 2023-09-20 06:16:24,870	INFO worker.py:1370 -- Calling ray.init() again after it has already been called.
# RayContext(dashboard_url='127.0.0.1:8266', python_version='3.8.8', ray_version='2.2.0', ray_commit='b6af0887ee5f2e460202133791ad941a41f15beb', address_info={'node_ip_address': '10.8.13.207', 'raylet_ip_address': '10.8.13.207', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2023-09-12_18-32-13_364285_87314/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2023-09-12_18-32-13_364285_87314/sockets/raylet', 'webui_url': '127.0.0.1:8266', 'session_dir': '/tmp/ray/session_2023-09-12_18-32-13_364285_87314', 'metrics_export_port': 64668, 'gcs_address': '10.8.13.207:38628', 'address': '10.8.13.207:38628', 'dashboard_agent_listen_port': 52365, 'node_id': '5a32b4af6d53fddb55bbc1b48df292f076bf92149df034e781c95e75'})

# %% [markdown]
# ## Prepare the Environment

# %%
from ray.tune.registry import register_env

def env_creator(env_config):
    return MalariaEnvironment()  # return an env instance

register_env("MalariaEnvironment", env_creator)
env = MalariaEnvironment()

config = A3CConfig()

# config = config.training(lr=0.01) #.rollouts(num_rollout_workers=1)
# config = config.framework(framework='tf2')

# Set the config object's env.
config = config.environment(env="MalariaEnvironment")

# %%
from scipy.stats import linregress, sem

# %%
from ray.tune.logger import pretty_print

config = A3CConfig()
# Print out some default values.
# print(config.sample_async)  
# Update the config object.
config = config.training( 
    lr=tune.grid_search([0.01, 0.001, 0.0001]), 
    entropy_coeff=tune.grid_search([0.01, 0.001, 0.0001])
)
# config = config.training(lr=0.01)
# config = config.training(lr=tune.grid_search([0.001, 0.01, 0.1]))
# config = config.rollouts(num_rollout_workers=1)
config = config.framework()

# Set the config object's env.
config = config.environment(env="MalariaEnvironment") 
# Use to_dict() to get the old-style python config dict
# when running with tune.

#pretty_print(config.to_dict())

# algo = config.build()
# Out:
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:03 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:03 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:03 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:03 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:03 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:03 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 76266 'SimpleBednet' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100014 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100025 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100040 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100051 Infected: 13702
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100057 Infected: 13702
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100070 Infected: 13702
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100081 Infected: 13702
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100093 Infected: 13702
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100104 Infected: 13702
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100106 Infected: 13702
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100116 Infected: 13702
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100127 Infected: 13702
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100133 Infected: 13702
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100132 Infected: 13692
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100104 Infected: 13656
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:16 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99627 Infected: 13170
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98921 Infected: 12452
# 00:00:17 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92909 Infected: 6430
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89768 Infected: 3281
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88154 Infected: 1660
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88137 Infected: 1641
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87855 Infected: 1351
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87863 Infected: 1351
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87662 Infected: 1145
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87671 Infected: 1145
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87503 Infected: 964
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87511 Infected: 962
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 0 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87376 Infected: 818
# 00:00:25 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:25 [0] [I] [Controller] Exiting execute_internal
# 00:00:25 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 455.93333333333334
#             Cost => 2.859975
#             Mean Parasitemia => 8787.038495794734
#             Disease Deaths => 4822.866666666667
#
# REWARD -11.987308333333333
# ACTION {'IRS': array([0.35868198], dtype=float32), 'ITNS': array([0.], dtype=float32)}
# Setting IRS to 0.35868197679519653
# Setting ITNS to 0.0
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
import tempfile
import time

import ray
from ray import train, tune
from ray.train import Checkpoint, FailureConfig, RunConfig
from ray.tune.schedulers import PopulationBasedTraining
from ray.tune.tune_config import TuneConfig
from ray.tune.tuner import Tuner
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-43-282f8ebb25c2> in <module>
#       8 import ray
#       9 from ray import train, tune
# ---> 10 from ray.train import Checkpoint, FailureConfig, RunConfig
#      11 from ray.tune.schedulers import PopulationBasedTraining
#      12 from ray.tune.tune_config import TuneConfig
#
# ImportError: cannot import name 'Checkpoint' from 'ray.train' (/opt/anaconda3/lib/python3.8/site-packages/ray/train/__init__.py)
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45908 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 56404 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46004 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100016 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45842 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46183 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100032 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46031 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100033 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45922 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100046 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45791 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100053 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45870 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100058 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45911 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100065 Infected: 13701
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45712 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100071 Infected: 13701
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45882 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100082 Infected: 13700
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46106 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13700
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45869 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100091 Infected: 13700
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46327 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100098 Infected: 13700
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45747 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45916 'IRSHousingModification' interventions at node 340461476
# 00:00:16 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45688 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:17 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45513 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 42679 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 41130 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40368 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40573 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40612 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40386 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40548 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40300 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40413 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40108 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40061 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:25 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:25 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:25 [0] [I] [Controller] Exiting execute_internal
# 00:00:25 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 103.98715
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -113.11581666666666
# ACTION {'IRS': array([0.26187348], dtype=float32), 'ITNS': array([0.70667326], dtype=float32)}
# Setting IRS to 0.2618734836578369
# Setting ITNS to 0.706673264503479
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45908 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 56404 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46004 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100016 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45842 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46183 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100032 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46031 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100033 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45922 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100046 Infected: 13701
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45791 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100053 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45870 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100058 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45911 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100065 Infected: 13701
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45712 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100071 Infected: 13701
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45882 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100082 Infected: 13700
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46106 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13700
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45869 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100091 Infected: 13700
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46327 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100098 Infected: 13700
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45747 'IRSHousingModification' interventions at node 340461476
# 00:00:16 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45916 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45688 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45513 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 42679 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 41130 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40368 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40573 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40612 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40386 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40548 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40300 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40413 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40108 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40061 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:27 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:27 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:27 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:27 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:27 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:27 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:27 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:27 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:27 [0] [I] [Controller] Exiting execute_internal
# 00:00:27 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 103.98715
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -113.11581666666666
# ACTION {'IRS': array([0.], dtype=float32), 'ITNS': array([0.14273539], dtype=float32)}
# Setting IRS to 0.0
# Setting ITNS to 0.14273539185523987
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45908 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 56404 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46004 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100016 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45842 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46183 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100032 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46031 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100033 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45922 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100046 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45791 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100053 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45870 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100058 Infected: 13701
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45911 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100065 Infected: 13701
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45712 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100071 Infected: 13701
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45882 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100082 Infected: 13700
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46106 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13700
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45869 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100091 Infected: 13700
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46327 'IRSHousingModification' interventions at node 340461476
# 00:00:16 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100098 Infected: 13700
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45747 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:17 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45916 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45688 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 45513 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 42679 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 41130 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40368 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40573 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40612 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40386 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40548 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40300 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40413 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40108 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:28 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 40061 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:28 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:28 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:28 [0] [I] [Controller] Exiting execute_internal
# 00:00:28 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 103.98715
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -113.11581666666666
# ACTION {'IRS': array([0.446317], dtype=float32), 'ITNS': array([0.81295776], dtype=float32)}
# Setting IRS to 0.44631698727607727
# Setting ITNS to 0.812957763671875
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35736 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 44765 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35755 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100016 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35624 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35857 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100032 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35820 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100033 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35407 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100046 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35346 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100053 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35463 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100058 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35619 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100065 Infected: 13701
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35476 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100071 Infected: 13701
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35461 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100082 Infected: 13700
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35716 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13700
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35588 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100091 Infected: 13700
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35882 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100098 Infected: 13700
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35400 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35677 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35393 'IRSHousingModification' interventions at node 340461476
# 00:00:16 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 35375 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 33052 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 31866 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 31142 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 31605 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 31472 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 31354 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 31454 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 31275 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 31210 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 31135 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 30945 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:24 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:24 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:24 [0] [I] [Controller] Exiting execute_internal
# 00:00:24 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 80.64709
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -89.77575666666667
# ACTION {'IRS': array([0.], dtype=float32), 'ITNS': array([0.21420282], dtype=float32)}
# Setting IRS to 0.0
# Setting ITNS to 0.21420282125473022
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# ...
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 75116 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 75156 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74990 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 74579 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 69796 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 67558 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66292 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66394 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66292 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66305 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66105 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 66009 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65978 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:28 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65923 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:29 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 65892 'IRSHousingModification' interventions at node 340461476
# 00:00:29 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:29 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:29 [0] [I] [Controller] Exiting execute_internal
# 00:00:29 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 6.2243325
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -15.352999166666667
# ACTION {'IRS': array([0.], dtype=float32), 'ITNS': array([0.], dtype=float32)}
# Setting IRS to 0.0
# Setting ITNS to 0.0
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:01 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:01 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:01 [0] [I] [Simulation] Merging node rank maps...
# 00:00:01 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:01 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:01 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:01 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:01 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:01 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:01 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2049 'IRSHousingModification' interventions at node 340461476
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:01 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 46187 'SimpleBednet' interventions at node 340461476
# 00:00:02 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2023 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100016 Infected: 13702
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2098 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2076 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100032 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2020 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100033 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2029 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100046 Infected: 13701
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1991 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100053 Infected: 13701
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2064 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100058 Infected: 13701
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2054 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100065 Infected: 13701
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1953 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100071 Infected: 13701
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1971 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100082 Infected: 13700
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2048 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13700
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1977 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100091 Infected: 13700
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2054 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100098 Infected: 13700
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2058 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2020 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2002 'IRSHousingModification' interventions at node 340461476
# 00:00:16 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:16 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 2065 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1851 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1805 'IRSHousingModification' interventions at node 340461476
# 00:00:19 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:19 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1795 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1805 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1827 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1728 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1786 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1807 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1785 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1703 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 1710 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:23 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:23 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:23 [0] [I] [Controller] Exiting execute_internal
# 00:00:23 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 6.2243325
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -15.352999166666667
# ACTION {'IRS': array([0.6556748], dtype=float32), 'ITNS': array([0.80896294], dtype=float32)}
# Setting IRS to 0.6556748151779175
# Setting ITNS to 0.8089629411697388
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /home/mbwie001/ms/MSC_EMOD

# %%
# https://docs.ray.io/en/latest/tune/examples/pbt_ppo_example.html
import random

import ray
from ray import air, tune
from ray.tune.schedulers import PopulationBasedTraining

hyperparam_mutations = {
    "lambda": lambda: random.uniform(0.9, 1.0),
    "clip_param": lambda: random.uniform(0.01, 0.5),
    "lr": [1e-3, 5e-4, 1e-4, 5e-5, 1e-5],
#         "num_sgd_iter": lambda: random.randint(1, 30),
#         "sgd_minibatch_size": lambda: random.randint(128, 16384),
#         "train_batch_size": lambda: random.randint(2000, 160000),
}

pbt = PopulationBasedTraining(
    time_attr="time_total_s",
    perturbation_interval=120,
    resample_probability=0.25,
    # Specifies the mutations of these hyperparams
    hyperparam_mutations=hyperparam_mutations,
    #custom_explore_fn=explore,
)

# Stop when we've either reached 100 training iterations or reward=300
stopping_criteria = {"training_iteration": 100, "episode_reward_mean": -20}

tuner = tune.Tuner(
    "A3C",
    tune_config=tune.TuneConfig(
        metric="episode_reward_mean",
        mode="max",
        scheduler=pbt
    ),
    param_space={
        "env": "MalariaEnvironment",
        "kl_coeff": 1.0,
        "num_workers": 4,
        "num_cpus": 64,  # number of CPUs to use per trial
        "num_gpus": 0,  # number of GPUs to use per trial
        "model": {"free_log_std": True},
        # These params are tuned from a fixed starting value.
        "lambda":  tune.grid_search([0.95, 0.5, 0.2, 1]),#0.95,
        "clip_param": 0.2,
        "lr": tune.grid_search([1e-3, 5e-4, 1e-4, 5e-5, 1e-5]),#1e-4,
        # These params start off randomly drawn from a set.
        "num_sgd_iter": tune.grid_search([10, 20, 30]),
        "sgd_minibatch_size":  tune.grid_search([128, 512, 2048]),
        "train_batch_size":  tune.grid_search([10000, 20000, 40000]),
    },
    #run_config=air.RunConfig(stop=stopping_criteria),
)
results = tuner.fit()
# Out:
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:A3C
# :actor_name:RolloutWorker
# :task_name:bundle_reservation_check_func
# :actor_name:A3C
# :actor_name:RolloutWorker
# ACTION OrderedDict([('IRS', array([0.7637219], dtype=float32)), ('ITNS', array([0.22852719], dtype=float32))])
# Setting IRS to 0.7637218832969666
# Setting ITNS to 0.22852718830108643
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /root/ray_results/A3C/A3C_MalariaEnvironment_8f3b8_00000_0_lambda=0.9500,lr=0.0010,num_sgd_iter=10,sgd_minibatch_size=128,train_batch_size=10000_2023-09-20_06-41-19
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:03 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:03 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:03 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:03 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:03 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:03 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100007 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 34435 'SimpleBednet' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100014 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100014 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100025 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100025 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100040 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100040 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100051 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100051 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100057 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100057 Infected: 13702
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100070 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100070 Infected: 13702
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100081 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100081 Infected: 13702
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100093 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100093 Infected: 13702
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100104 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100104 Infected: 13702
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100106 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100106 Infected: 13702
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100116 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100116 Infected: 13702
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100127 'IRSHousingModification' interventions at node 340461476
# 00:00:13 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100127 Infected: 13702
# 00:00:13 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100133 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100133 Infected: 13702
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100132 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100132 Infected: 13692
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100104 'IRSHousingModification' interventions at node 340461476
# 00:00:16 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100104 Infected: 13656
# 00:00:17 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 99627 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99627 Infected: 13170
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 98921 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98921 Infected: 12452
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 92909 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92909 Infected: 6430
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 89768 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89768 Infected: 3281
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 88154 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88154 Infected: 1660
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 88137 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88137 Infected: 1641
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87855 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87855 Infected: 1351
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87863 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87863 Infected: 1351
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87662 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87662 Infected: 1145
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87671 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87671 Infected: 1145
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87503 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87503 Infected: 964
# 00:00:28 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87511 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87511 Infected: 962
# 00:00:28 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 87376 'IRSHousingModification' interventions at node 340461476
# 00:00:29 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87376 Infected: 818
# 00:00:29 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:29 [0] [I] [Controller] Exiting execute_internal
# 00:00:29 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 455.93333333333334
#             Cost => 223.06868
#             Mean Parasitemia => 8787.038495794734
#             Disease Deaths => 4822.866666666667
#
# REWARD -232.19601333333333
# ACTION {'IRS': array([0.27403176], dtype=float32), 'ITNS': array([0.04588932], dtype=float32)}
# Setting IRS to 0.27403175830841064
# Setting ITNS to 0.045889317989349365
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /root/ray_results/A3C/A3C_MalariaEnvironment_8f3b8_00000_0_lambda=0.9500,lr=0.0010,num_sgd_iter=10,sgd_minibatch_size=128,train_batch_size=10000_2023-09-20_06-41-19
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:01 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:01 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:01 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:01 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:01 [0] [I] [Simulation] Merging node rank maps...
# 00:00:01 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:01 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:01 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:01 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100007 'IRSHousingModification' interventions at node 340461476
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 34435 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100014 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100014 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100025 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100025 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 100040 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100040 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 
[0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:30 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:30 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:30 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:30 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:30 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:30 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:30 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:30 [0] [I] [Controller] Exiting execute_internal
# 00:00:30 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 455.93333333333334
#             Cost => 223.06868
#             Mean Parasitemia => 8787.038495794734
#             Disease Deaths => 4822.866666666667
#
# REWARD -232.19601333333333
# ACTION {'IRS': array([0.17776346], dtype=float32), 'ITNS': array([0.6292006], dtype=float32)}
# Setting IRS to 0.1777634620666504
# Setting ITNS to 0.6292005777359009
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /root/ray_results/A3C/A3C_MalariaEnvironment_8f3b8_00000_0_lambda=0.9500,lr=0.0010,num_sgd_iter=10,sgd_minibatch_size=128,train_batch_size=10000_2023-09-20_06-41-19
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# ...
# 00:00:18 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 21431 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 21500 'IRSHousingModification' interventions at node 340461476
# 00:00:22 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:22 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 20041 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:23 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 19271 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 19006 'IRSHousingModification' interventions at node 340461476
# 00:00:24 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 18926 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 19154 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 19042 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 19049 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 18941 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 18872 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:28 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 18924 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:29 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 18804 'IRSHousingModification' interventions at node 340461476
# 00:00:29 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:29 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:29 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:29 [0] [I] [Controller] Exiting execute_internal
# 00:00:29 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 49.396935
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -58.52560166666667
# ACTION {'IRS': array([0.61887467], dtype=float32), 'ITNS': array([0.], dtype=float32)}
# Setting IRS to 0.6188746690750122
# Setting ITNS to 0.0
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /root/ray_results/A3C/A3C_MalariaEnvironment_8f3b8_00000_0_lambda=0.9500,lr=0.0010,num_sgd_iter=10,sgd_minibatch_size=128,train_batch_size=10000_2023-09-20_06-41-19
# Intellectual Ventures(R)/EMOD Disease Transmission Kernel 2.20.17.0
# Built on Apr  9 2019 by idm_bamboo_user from master(2d8a9f2) checked in on 2019-04-05 15:49:43 -0700
# Supports sim_types: GENERIC, VECTOR, MALARIA, AIRBORNE, TBHIV, STI, HIV, PY, TYPHOID, ENVIRONMENTAL.
#
# Using config file: config.json
# Using input path: .
# Using output path: output
# Using dll path:
# Python not initialized because --python-script-path (-P) not set.
# Initializing environment...
# Log-levels:
# 	Default -> INFO
# 	Eradication -> INFO
# 00:00:00 [0] [I] [Eradication] Loaded Configuration...
# 00:00:00 [0] [I] [Eradication] 199 parameters found.
# 00:00:00 [0] [I] [Eradication] Initializing Controller...
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal()...
# 00:00:00 [0] [I] [RandomNumberGeneratorFactory] Using USE_PSEUDO_DES random number generator.
# 00:00:00 [0] [I] [Controller] DefaultController::execute_internal() populate simulation...
# 00:00:00 [0] [I] [Simulation] Campaign file name identified as: campaign.json
# 00:00:00 [0] [I] [Climate] Initialize
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [W] [Climate] No 'WeatherSchemaVersion' found in climate file metadata. Falling back to 'NodeCount' and 'NumberDTKNodes'
# 00:00:00 [0] [I] [LoadBalanceScheme] Using Checkerboard Load Balance Scheme.
# 00:00:02 [0] [I] [Simulation] Looking for campaign file campaign.json
# 00:00:02 [0] [I] [Simulation] Found campaign file successfully.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Number_Repetitions" : 1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Timesteps_Between_Repetitions" : -1 ) for unspecified parameter.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() created 1 nodes
# 00:00:02 [0] [I] [Simulation] populateFromDemographics() generated 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank 0 contributes 1 nodes...
# 00:00:02 [0] [I] [Simulation] Merging node rank maps...
# 00:00:02 [0] [I] [Simulation] Merged rank 0 map now has 1 nodes.
# 00:00:02 [0] [I] [Simulation] Rank map contents not displayed until NodeRankMap::ToString() (re)implemented.
# 00:00:02 [0] [I] [Simulation] Initialized 'InsetChart.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'BinnedReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'DemographicsSummary.json' reporter
# 00:00:02 [0] [I] [Simulation] Initialized 'VectorSpeciesReport.json' reporter
# 00:00:02 [0] [I] [Simulation] Update(): Time: 1.0 Rank: 0 StatPop: 100000 Infected: 13704
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [SimulationEventContext] Time for campaign event. Calling Dispatch...
# 00:00:02 [0] [I] [SimulationEventContext] 1 node(s) visited.
# 00:00:02 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "IRSHousingModification" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91475 'IRSHousingModification' interventions at node 340461476
# 00:00:03 [0] [I] [JsonConfigurable] Using the default value ( "Intervention_Name" : "SimpleBednet" ) for unspecified parameter.
# 00:00:03 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 30136 'SimpleBednet' interventions at node 340461476
# 00:00:03 [0] [I] [Simulation] Update(): Time: 2.0 Rank: 0 StatPop: 100007 Infected: 13702
# 00:00:04 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91538 'IRSHousingModification' interventions at node 340461476
# 00:00:04 [0] [I] [Simulation] Update(): Time: 3.0 Rank: 0 StatPop: 100016 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91519 'IRSHousingModification' interventions at node 340461476
# 00:00:05 [0] [I] [Simulation] Update(): Time: 4.0 Rank: 0 StatPop: 100029 Infected: 13702
# 00:00:05 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91509 'IRSHousingModification' interventions at node 340461476
# 00:00:06 [0] [I] [Simulation] Update(): Time: 5.0 Rank: 0 StatPop: 100032 Infected: 13702
# 00:00:06 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91545 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 6.0 Rank: 0 StatPop: 100033 Infected: 13702
# 00:00:07 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91516 'IRSHousingModification' interventions at node 340461476
# 00:00:07 [0] [I] [Simulation] Update(): Time: 7.0 Rank: 0 StatPop: 100046 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91402 'IRSHousingModification' interventions at node 340461476
# 00:00:08 [0] [I] [Simulation] Update(): Time: 8.0 Rank: 0 StatPop: 100053 Infected: 13701
# 00:00:08 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91636 'IRSHousingModification' interventions at node 340461476
# 00:00:09 [0] [I] [Simulation] Update(): Time: 9.0 Rank: 0 StatPop: 100058 Infected: 13701
# 00:00:09 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91486 'IRSHousingModification' interventions at node 340461476
# 00:00:10 [0] [I] [Simulation] Update(): Time: 10.0 Rank: 0 StatPop: 100065 Infected: 13701
# 00:00:10 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91371 'IRSHousingModification' interventions at node 340461476
# 00:00:11 [0] [I] [Simulation] Update(): Time: 11.0 Rank: 0 StatPop: 100071 Infected: 13701
# 00:00:11 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91493 'IRSHousingModification' interventions at node 340461476
# 00:00:12 [0] [I] [Simulation] Update(): Time: 12.0 Rank: 0 StatPop: 100082 Infected: 13700
# 00:00:12 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91626 'IRSHousingModification' interventions at node 340461476
# 00:00:14 [0] [I] [Simulation] Update(): Time: 13.0 Rank: 0 StatPop: 100084 Infected: 13700
# 00:00:14 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91454 'IRSHousingModification' interventions at node 340461476
# 00:00:15 [0] [I] [Simulation] Update(): Time: 14.0 Rank: 0 StatPop: 100091 Infected: 13700
# 00:00:15 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91482 'IRSHousingModification' interventions at node 340461476
# 00:00:17 [0] [I] [Simulation] Update(): Time: 15.0 Rank: 0 StatPop: 100098 Infected: 13700
# 00:00:17 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91438 'IRSHousingModification' interventions at node 340461476
# 00:00:18 [0] [I] [Simulation] Update(): Time: 16.0 Rank: 0 StatPop: 100101 Infected: 13695
# 00:00:18 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91413 'IRSHousingModification' interventions at node 340461476
# 00:00:20 [0] [I] [Simulation] Update(): Time: 17.0 Rank: 0 StatPop: 100069 Infected: 13656
# 00:00:20 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 91110 'IRSHousingModification' interventions at node 340461476
# 00:00:21 [0] [I] [Simulation] Update(): Time: 18.0 Rank: 0 StatPop: 99614 Infected: 13190
# 00:00:21 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 90597 'IRSHousingModification' interventions at node 340461476
# 00:00:23 [0] [I] [Simulation] Update(): Time: 19.0 Rank: 0 StatPop: 98930 Infected: 12491
# 00:00:24 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 84874 'IRSHousingModification' interventions at node 340461476
# 00:00:25 [0] [I] [Simulation] Update(): Time: 20.0 Rank: 0 StatPop: 92884 Infected: 6436
# 00:00:25 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 82056 'IRSHousingModification' interventions at node 340461476
# 00:00:26 [0] [I] [Simulation] Update(): Time: 21.0 Rank: 0 StatPop: 89720 Infected: 3265
# 00:00:26 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80548 'IRSHousingModification' interventions at node 340461476
# 00:00:27 [0] [I] [Simulation] Update(): Time: 22.0 Rank: 0 StatPop: 88170 Infected: 1708
# 00:00:27 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80579 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 23.0 Rank: 0 StatPop: 88158 Infected: 1685
# 00:00:28 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80411 'IRSHousingModification' interventions at node 340461476
# 00:00:28 [0] [I] [Simulation] Update(): Time: 24.0 Rank: 0 StatPop: 87886 Infected: 1409
# 00:00:29 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80467 'IRSHousingModification' interventions at node 340461476
# 00:00:29 [0] [I] [Simulation] Update(): Time: 25.0 Rank: 0 StatPop: 87895 Infected: 1409
# 00:00:29 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80232 'IRSHousingModification' interventions at node 340461476
# 00:00:30 [0] [I] [Simulation] Update(): Time: 26.0 Rank: 0 StatPop: 87677 Infected: 1182
# 00:00:30 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80302 'IRSHousingModification' interventions at node 340461476
# 00:00:31 [0] [I] [Simulation] Update(): Time: 27.0 Rank: 0 StatPop: 87685 Infected: 1182
# 00:00:31 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79962 'IRSHousingModification' interventions at node 340461476
# 00:00:31 [0] [I] [Simulation] Update(): Time: 28.0 Rank: 0 StatPop: 87475 Infected: 969
# 00:00:32 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 80068 'IRSHousingModification' interventions at node 340461476
# 00:00:32 [0] [I] [Simulation] Update(): Time: 29.0 Rank: 0 StatPop: 87479 Infected: 967
# 00:00:32 [0] [I] [StandardEventCoordinator] UpdateNodes() gave out 79765 'IRSHousingModification' interventions at node 340461476
# 00:00:33 [0] [I] [Simulation] Update(): Time: 30.0 Rank: 0 StatPop: 87311 Infected: 792
# 00:00:33 [0] [I] [Simulation] Finalizing 'InsetChart.json' reporter.
# 00:00:33 [0] [I] [Simulation] Finalized  'InsetChart.json' reporter.
# 00:00:33 [0] [I] [Simulation] Finalizing 'BinnedReport.json' reporter.
# 00:00:33 [0] [I] [Simulation] Finalized  'BinnedReport.json' reporter.
# 00:00:33 [0] [I] [Simulation] Finalizing 'DemographicsSummary.json' reporter.
# 00:00:33 [0] [I] [Simulation] Finalized  'DemographicsSummary.json' reporter.
# 00:00:33 [0] [I] [Simulation] Finalizing 'VectorSpeciesReport.json' reporter.
# 00:00:33 [0] [I] [Simulation] Finalized  'VectorSpeciesReport.json' reporter.
# 00:00:33 [0] [I] [Controller] Exiting execute_internal
# 00:00:33 [0] [I] [Eradication] Controller executed successfully.
#
#
#             Infected => 456.8
#             Severe Cases => 456.06666666666666
#             Cost => 203.92002
#             Mean Parasitemia => 8848.656452560403
#             Disease Deaths => 4812.433333333333
#
# REWARD -213.04868666666667
# ACTION {'IRS': array([1.], dtype=float32), 'ITNS': array([0.], dtype=float32)}
# Setting IRS to 1.0
# Setting ITNS to 0.0
#
#
# *** WRITING TO CAMPAIGNS FILE ***
# *** SUCCESSFULLY CHANGED CAMPAIGNS FILE***
#
#
# Action is setTrue
#
# Starting Simulation...
#
# /root/ray_results/A3C/A3C_MalariaEnvironment_8f3b8_00000_0_lambda=0.9500,lr=0.0010,num_sgd_iter=10,sgd_minibatch_size=128,train_batch_size=10000_2023-09-20_06-41-19

# %%
import pprint

best_result = results.get_best_result()

print("Best performing trial's final set of hyperparameters:\n")
pprint.pprint(
    {k: v for k, v in best_result.config.items() if k in hyperparam_mutations}
)

print("\nBest performing trial's final reported metrics:\n")

metrics_to_print = [
    "episode_reward_mean",
    "episode_reward_max",
    "episode_reward_min",
    "episode_len_mean",
]
pprint.pprint({k: v for k, v in best_result.metrics.items() if k in metrics_to_print})

# %%
df = results.get_dataframe()

# %%
df.head()

# %%
if results.errors:
    raise RuntimeError

# %%
from pbt_visualization_utils import (
    get_init_theta,
    plot_parameter_history,
    plot_Q_history,
    make_animation,
)

# %%
fig, axs = plt.subplots(1, 2, figsize=(13, 6), gridspec_kw=dict(width_ratios=[1.5, 1]))

colors = ["black", "red"]
labels = ["h = [1, 0]", "h = [0, 1]"]

plot_parameter_history(
    results,
    colors,
    labels,
    perturbation_interval=120,
    fig=fig,
    ax=axs[0],
)
plot_Q_history(grid_results, colors, labels, ax=axs[1])
